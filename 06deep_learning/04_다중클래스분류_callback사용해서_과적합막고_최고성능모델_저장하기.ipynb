# %% [markdown]
# # 가상환경 tf에서 진행중임

# %% [markdown]
# # 04_다중클래스분류_callback사용해서_과적합막고_최고성능모델_저장하기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
data = pd.read_csv("./data/winequality-white.csv", sep=";")
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
data['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler

# %%
X = data.drop('quality', axis=1)
y = data['quality']

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol
# 0         8.8
# 1         9.5
# 2        10.1
# 3         9.9
# 4         9.9
# ...       ...
# 4893     11.2
# 4894      9.6
# 4895      9.4
# 4896     12.8
# 4897     11.8
#
# [4898 rows x 11 columns]

# %%
y = pd.get_dummies(y)
y
# Out:
#           3      4      5      6      7      8      9
# 0     False  False  False   True  False  False  False
# 1     False  False  False   True  False  False  False
# 2     False  False  False   True  False  False  False
# 3     False  False  False   True  False  False  False
# 4     False  False  False   True  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...
# 4893  False  False  False   True  False  False  False
# 4894  False  False   True  False  False  False  False
# 4895  False  False  False   True  False  False  False
# 4896  False  False  False  False   True  False  False
# 4897  False  False  False   True  False  False  False
#
# [4898 rows x 7 columns]

# %%
data['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.4, stratify=y, random_state=42)
X_valid, X_test, y_valid, y_test = train_test_split(X_valid, y_valid, test_size=0.5, stratify=y_valid, random_state=42)

# %%
rs = RobustScaler()
train_temp = rs.fit_transform(X_train)
valid_temp = rs.transform(X_valid)
test_temp = rs.transform(X_test)
rs_X_train = pd.DataFrame(train_temp, columns=X_train.columns, index=X_train.index)
rs_X_valid = pd.DataFrame(valid_temp, columns=X_valid.columns, index=X_valid.index)
rs_X_test = pd.DataFrame(test_temp, columns=X_test.columns, index=X_test.index)

# %%
rs_X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3940       0.090909          1.272727     0.416667        0.451220   0.714286
# 3905      -0.272727          0.636364    -0.166667       -0.170732  -0.500000
# 53        -0.363636         -0.727273     0.250000       -0.512195   0.142857
# 2576      -0.272727          0.090909     0.666667        0.585366  -0.285714
# 1970       1.363636          2.090909     0.916667       -0.329268  -0.500000
# ...             ...               ...          ...             ...        ...
# 2609       0.272727         -0.545455    -0.166667       -0.524390  -1.714286
# 2530      -0.909091          0.363636    -1.666667       -0.439024  -0.500000
# 1231       1.000000          1.363636     0.416667       -0.085366  -0.928571
# 3948      -1.000000         -1.090909    -0.166667        0.024390   0.142857
# 2460      -0.181818          0.636364    -0.666667        1.323171   0.142857
#
#       free sulfur dioxide  total sulfur dioxide   density    pH  sulphates  \
# 3940             0.090909              0.216667  0.507205 -0.05   0.142857
# 3905             0.000000             -0.783333 -0.811527  0.40   1.071429
# 53               0.227273             -0.450000 -0.622478  0.70  -0.928571
# 2576             1.818182              1.533333  0.465706  0.05   0.142857
# 1970            -0.090909             -0.316667  0.138329  0.30  -0.071429
# ...                   ...                   ...       ...   ...        ...
# 2609            -1.363636             -1.783333 -1.035159  0.15  -0.857143
# 2530             1.045455              0.466667 -0.325072  1.05   0.785714
# 1231             0.272727             -0.350000 -0.414986  0.00   0.428571
# 3948            -0.363636             -0.500000  0.205187  0.75  -0.214286
# 2460            -0.136364              0.200000  1.019020 -0.45   0.285714
#
#        alcohol
# 3940 -0.578947
# 3905  1.105263
# 53    0.263158
# 2576 -0.526316
# 1970  0.157895
# ...        ...
# 2609  0.842105
# 2530  0.052632
# 1231  1.052632
# 3948 -0.578947
# 2460 -0.631579
#
# [2938 rows x 11 columns]

# %%
y_train
# Out:
#           3      4      5      6      7      8      9
# 3940  False  False   True  False  False  False  False
# 3905  False  False  False  False   True  False  False
# 53    False  False  False   True  False  False  False
# 2576  False  False   True  False  False  False  False
# 1970  False  False  False   True  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...
# 2609  False  False  False   True  False  False  False
# 2530  False  False  False   True  False  False  False
# 1231  False  False  False  False   True  False  False
# 3948  False  False   True  False  False  False  False
# 2460  False  False   True  False  False  False  False
#
# [2938 rows x 7 columns]

# %%
y_train.shape[1]
# Out:
# 7

# %% [markdown]
# # 모델을 최고 성능에서 저장하고 중지하기

# %%
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
data['quality'].nunique()
# Out:
# 7

# %%
n_class = y_train.shape[1]
model = Sequential()
model.add(Input(shape=(rs_X_train.shape[1],)))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(16, activation = 'relu'))
model.add(Dense(n_class, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_11 (Dense)                │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 7)              │           119 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,495 (13.65 KB)
#  Trainable params: 3,495 (13.65 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import os

# %%
model.compile(loss="categorical_crossentropy", optimizer='adam', metrics=['accuracy'])
early_stop = EarlyStopping(patience=1000)
os.makedirs("./model", exist_ok=True) # 디렉토리자동생성
filepath = "./model/whitewine_loss:{val_loss:04f}_epoch_{epoch:04d}_.keras"
model_save = ModelCheckpoint(filepath=filepath, save_best_only=True)
history = model.fit(rs_X_train, y_train, epochs=10000, batch_size=32, validation_data=(rs_X_valid, y_valid),
                    callbacks=[early_stop, model_save])

plt.figure(figsize=(8,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend(['train', 'valid'])
plt.show()
# Out:
# Epoch 1/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9838 - loss: 0.0540 - val_accuracy: 0.5796 - val_loss: 7.0497
# Epoch 2/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9889 - loss: 0.0354 - val_accuracy: 0.5776 - val_loss: 7.0812
# Epoch 3/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9840 - loss: 0.0567 - val_accuracy: 0.5867 - val_loss: 7.0660
# Epoch 4/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9828 - loss: 0.0627 - val_accuracy: 0.5735 - val_loss: 7.0889
# Epoch 5/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9789 - loss: 0.0613 - val_accuracy: 0.5796 - val_loss: 7.1264
# Epoch 6/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9946 - loss: 0.0232 - val_accuracy: 0.5878 - val_loss: 7.0598
# Epoch 7/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9972 - loss: 0.0172 - val_accuracy: 0.5878 - val_loss: 7.0395
# Epoch 8/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9971 - loss: 0.0161 - val_accuracy: 0.5878 - val_loss: 7.0796
# Epoch 9/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9945 - loss: 0.0272 - val_accuracy: 0.5847 - val_loss: 7.0637
# Epoch 10/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9974 - loss: 0.0164 - val_accuracy: 0.5745 - val_loss: 7.1130
# Epoch 11/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9761 - loss: 0.0724 - val_accuracy: 0.5735 - val_loss: 7.2963
# Epoch 12/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9685 - loss: 0.0882 - val_accuracy: 0.5776 - val_loss: 7.2709
# Epoch 13/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9440 - loss: 0.1544 - val_accuracy: 0.5837 - val_loss: 7.0489
# Epoch 14/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9810 - loss: 0.0592 - val_accuracy: 0.5857 - val_loss: 7.1328
# Epoch 15/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9885 - loss: 0.0436 - val_accuracy: 0.5898 - val_loss: 7.1030
# Epoch 16/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9977 - loss: 0.
10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9987 - loss: 0.0079 - val_accuracy: 0.5837 - val_loss: 8.5529
# Epoch 718/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9986 - loss: 0.0078 - val_accuracy: 0.5898 - val_loss: 8.5607
# Epoch 719/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9964 - loss: 0.0125 - val_accuracy: 0.5857 - val_loss: 8.6455
# Epoch 720/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9993 - loss: 0.0086 - val_accuracy: 0.5898 - val_loss: 8.6511
# Epoch 721/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9968 - loss: 0.0117 - val_accuracy: 0.5806 - val_loss: 8.5828
# Epoch 722/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9966 - loss: 0.0156 - val_accuracy: 0.5857 - val_loss: 8.6570
# Epoch 723/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.0113 - val_accuracy: 0.5776 - val_loss: 8.5582
# Epoch 724/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9972 - loss: 0.0127 - val_accuracy: 0.5898 - val_loss: 8.6166
# Epoch 725/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9965 - loss: 0.0126 - val_accuracy: 0.5786 - val_loss: 8.6031
# Epoch 726/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.0133 - val_accuracy: 0.5939 - val_loss: 8.5605
# Epoch 727/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9978 - loss: 0.0158 - val_accuracy: 0.5847 - val_loss: 8.6035
# Epoch 728/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9981 - loss: 0.0079 - val_accuracy: 0.5816 - val_loss: 8.5803
# Epoch 729/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9971 - loss: 0.0133 - val_accuracy: 0.5827 - val_loss: 8.6102
# Epoch 730/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9985 - loss: 0.0095 - val_accuracy: 0.5806 - val_loss: 8.6290
# Epoch 731/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9952 - loss: 0.0269 - val_accuracy: 0.5878 - val_loss: 8.6571
# Epoch 732/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9870 - loss: 0.0491 - val_accuracy: 0.5622 - val_loss: 8.6599
# Epoch 733/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9196 - loss: 0.3644 - val_accuracy: 0.5694 - val_loss: 8.5535
# Epoch 734/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9696 - loss: 0.1007 - val_accuracy: 0.5827 - val_loss: 8.9396
# Epoch 735/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9805 - loss: 0.0525 - val_accuracy: 0.5867 - val_loss: 8.6573
# Epoch 736/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9936 - loss: 0.0257 - val_accuracy: 0.5857 - val_loss: 8.4162
# Epoch 737/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9976 - loss: 0.0120 - val_accuracy: 0.5867 - val_loss: 8.5231
# Epoch 738/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9976 - loss: 0.0127 - val_accuracy: 0.5796 - val_loss: 8.5636
# Epoch 739/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9973 - loss: 0.0111 - val_accuracy: 0.5867 - val_loss: 8.5366
# Epoch 740/10000
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9977 - loss: 0.0090 - val_accuracy: 0.5918 - val_loss: 8.5575
# Epoch 741/10000
#  1/92 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0045
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 6
#       4 filepath = "./model/whitewine_loss:{val_loss:04f}_epoch_{epoch:04d}_.keras"
#       5 model_save = ModelCheckpoint(filepath=filepath, save_best_only=True)
# ----> 6 history = model.fit(rs_X_train, y_train, epochs=10000, batch_size=32, validation_data=(rs_X_valid, y_valid),
#       7                     callbacks=[early_stop, model_save])
#       9 plt.figure(figsize=(8,5))
#      10 plt.plot(history.history['loss'])
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:132, in call_function(args, kwargs, tracing_options)
#     130 args = args if args else ()
#     131 kwargs = kwargs if kwargs else {}
# --> 132 function = trace_function(
#     133     args=args, kwargs=kwargs, tracing_options=tracing_options
#     134 )
#     136 # Bind it ourselves to skip unnecessary canonicalization of default call.
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:230, in _maybe_define_function(args, kwargs, tracing_options)
#     220 current_func_context = function_context.make_function_context(
#     221     tracing_options.scope_type
#     222 )
#     224 capture_types = (
#     225     tracing_options.function_captures.capture_types
#     226     if tracing_options.function_captures
#     227     else {}
#     228 )
#     229 lookup_func_type, lookup_func_context = (
# --> 230     function_type_utils.make_canonicalized_monomorphic_type(
#     231         args,
#     232         kwargs,
#     233         capture_types,
#     234         tracing_options.polymorphic_type,
#     235     )
#     236 )
#     238 if tracing_options.function_cache is not None:
#     239   concrete_function = tracing_options.function_cache.lookup(
#     240       lookup_func_type, current_func_context
#     241   )
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/function_type_utils.py:375, in make_canonicalized_monomorphic_type(args, kwargs, capture_types, polymorphic_type)
#     368 """Generates function type given the function arguments."""
#     369 kwargs = {
#     370     function_type_lib.sanitize_arg_name(name): value
#     371     for name, value in kwargs.items()
#     372 }
#     374 function_type, type_context = (
# --> 375     function_type_lib.canonicalize_to_monomorphic(
#     376         args, kwargs, {}, capture_types, polymorphic_type
#     377     )
#     378 )
#     380 return function_type, type_context
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/tensorflow/core/function/polymorphism/function_type.py:587, in canonicalize_to_monomorphic(args, kwargs, default_values, capture_types, polymorphic_type)
#     581       parameters.append(
#     582           _make_validated_mono_param(kwarg_name, arg[kwarg_name],
#     583                                      Parameter.KEYWORD_ONLY, type_context,
#     584                                      poly_parameter.type_constraint))
#     585   else:
#     586     parameters.append(
# --> 587         _make_validated_mono_param(name, arg, poly_parameter.kind,
#     588                                    type_context,
#     589                                    poly_parameter.type_constraint))
#     591 return FunctionType(parameters, capture_types), type_context
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/tensorflow/core/function/polymorphism/function_type.py:526, in _make_validated_mono_param(name, value, kind, type_context, poly_type)
#     522 def _make_validated_mono_param(
#     523     name, value, kind, type_context, poly_type
#     524 ) -> Parameter:
#     525   """Generates and validates a parameter for Monomorphic FunctionType."""
# --> 526   mono_type = trace_type.from_value(value, type_context)
#     528   if poly_type and not mono_type.is_subtype_of(poly_type):
#     529     raise TypeError(f"Parameter `{name}` was expected to be of type "
#     530                     f"{poly_type} but is {mono_type}")
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/tensorflow/core/function/trace_type/trace_type_builder.py:144, in from_value(value, context)
#     142 if context.is_legacy_signature and isinstance(value, trace.TraceType):
#     143   return value
# --> 144 elif isinstance(value, trace.SupportsTracingProtocol):
#     145   generated_type = value.__tf_tracing_type__(context)
#     146   if not isinstance(generated_type, trace.TraceType):
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/typing_extensions.py:631, in _ProtocolMeta.__instancecheck__(cls, instance)
#     629 if cls is Protocol:
#     630     return type.__instancecheck__(cls, instance)
# --> 631 if not getattr(cls, "_is_protocol", False):
#     632     # i.e., it's a concrete subclass of a protocol
#     633     return abc.ABCMeta.__instancecheck__(cls, instance)
#     635 if (
#     636     not getattr(cls, '_is_runtime_protocol', False) and
#     637     not _allow_reckless_class_checks()
#     638 ):
#
# KeyboardInterrupt:

# %% [markdown]
# # 데이터 증폭 후 분석
# * 데이터 증폭 + 스케일러 사용 시에는 :
# * 데이터 증폭 후 스케일러로 스케일링 하기

# %%
from imblearn.over_sampling import SMOTE

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
X = data.drop('quality', axis=1)
y = data['quality']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.4, stratify=y, random_state=42)
X_valid, X_test, y_valid, y_test = train_test_split(X_valid, y_valid, test_size=0.5, stratify=y_valid, random_state=42)

# %%
smt = SMOTE(n_jobs=-1, random_state=42)
smt_X_trian, smt_y_train = smt.fit_resample(X_train, y_train)
smt_X_trian = pd.DataFrame(smt_X_trian, columns=X_train.columns, index=X_train.index)
smt_y_train = pd.DataFrame(smt_y_train, columns=y_train.columns, index=y_train.index)
# Out:
# /home/fintech_ubuntu/miniforge3/envs/tf/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /home/fintech_ubuntu/miniforge3/envs/tf/lib/python3.9/site-packages/imblearn/over_sampling/_smote/base.py:370: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 2
#       1 smt = SMOTE(n_jobs=-1, random_state=42)
# ----> 2 smt_X_trian, smt_y_train = smt.fit_resample(X_train, y_train)
#       3 smt_X_trian = pd.DataFrame(smt_X_trian, columns=X_train.columns, index=X_train.index)
#       4 smt_y_train = pd.DataFrame(smt_y_train, columns=y_train.columns, index=y_train.index)
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/imblearn/base.py:208, in BaseSampler.fit_resample(self, X, y)
#     187 """Resample the dataset.
#     188
#     189 Parameters
#    (...)
#     205     The corresponding label of `X_resampled`.
#     206 """
#     207 self._validate_params()
# --> 208 return super().fit_resample(X, y)
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/imblearn/base.py:112, in SamplerMixin.fit_resample(self, X, y)
#     106 X, y, binarize_y = self._check_X_y(X, y)
#     108 self.sampling_strategy_ = check_sampling_strategy(
#     109     self.sampling_strategy, y, self._sampling_type
#     110 )
# --> 112 output = self._fit_resample(X, y)
#     114 y_ = (
#     115     label_binarize(output[1], classes=np.unique(y)) if binarize_y else output[1]
#     116 )
#     118 X_, y_ = arrays_transformer.transform(output[0], y_)
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/imblearn/over_sampling/_smote/base.py:389, in SMOTE._fit_resample(self, X, y)
#     386 X_class = _safe_indexing(X, target_class_indices)
#     388 self.nn_k_.fit(X_class)
# --> 389 nns = self.nn_k_.kneighbors(X_class, return_distance=False)[:, 1:]
#     390 X_new, y_new = self._make_samples(
#     391     X_class, y.dtype, class_sample, X_class, nns, n_samples, 1.0
#     392 )
#     393 X_resampled.append(X_new)
#
# File ~/miniforge3/envs/tf/lib/python3.9/site-packages/sklearn/neighbors/_base.py:854, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     852     else:
#     853         inequality_str = "n_neighbors <= n_samples_fit"
# --> 854     raise ValueError(
#     855         f"Expected {inequality_str}, but "
#     856         f"n_neighbors = {n_neighbors}, n_samples_fit = {n_samples_fit}, "
#     857         f"n_samples = {X.shape[0]}"  # include n_samples for common tests
#     858     )
#     860 n_jobs = effective_n_jobs(self.n_jobs)
#     861 chunked_results = None
#
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 6, n_samples_fit = 3, n_samples = 3

# %%
rs = RobustScaler()
train_temp = rs.fit_transform(X_train)
valid_temp = rs.transform(X_valid)
test_temp = rs.transform(X_test)
rs_X_train = pd.DataFrame(train_temp, columns=X_train.columns, index=X_train.index)
rs_X_valid = pd.DataFrame(valid_temp, columns=X_valid.columns, index=X_valid.index)
rs_X_test = pd.DataFrame(test_temp, columns=X_test.columns, index=X_test.index)
