# %% [markdown]
# # 이미지 데이터 훈련을 위한 전처리
# * 정규화 = X /255 => 0-1 범위로 변환 또는 -1 - 1 범위로 변환할 것
# * y 종속변수 = one-hot encoding(get_dummies와 유사), to_categorical()(keras)

# %%
X_train[0].shpae

# %%
X_train = X_train.reshape(X_train.shpae[0], 784) # 784 = X_train[0].shape의 값인 28에 *28한 값이므로
