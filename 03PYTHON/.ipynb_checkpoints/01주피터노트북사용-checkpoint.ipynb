# %% [markdown]
# ### 링크걸기
# .[네이버링크].(https://www.naver.com)
#
# ### 이미지 넣기
# ![고양이].
#
# ### 수식 넣기
# -

# %%
long_char3 = "문자열은 아무리 길이가 길어도 한줄로 되어 있어야 한다.\줄바꿈이 안된다. 줄바꿈을 하고 싶으면 \"\"\ 안에 넣으면 된다."

# %%
print(long_char3)
# Out:
# 문자열은 아무리 길이가 길어도 한줄로 되어 있어야 한다.\줄바꿈이 안된다. 줄바꿈을 하고 싶으면 ""\ 안에 넣으면 된다.

# %%
long_char5 = """따옴표 3개로 문자열을 감싸면 줄바꿈을 해도 모두 그대로 출력이 된다.
쌍따옴표 3개나 홀따옴표 3개로 감싸면 된다"""

# %%
print(long_char5)
# Out:
# 따옴표 3개로 문자열을 감싸면 줄바꿈을 해도 모두 그대로 출력이 된다.
# 쌍따옴표 3개나 홀따옴표 3개로 감싸면 된다

# %%
long_char6 = '''따옴표 3개로 문자열을 감싸면 줄바꿈을 해도
모두 그대로 출력이 된다.
쌍따옴표 3개나 홀따옴표 3개로 감싸면 된다'''

# %%
print(long_char6)
# Out:
# 따옴표 3개로 문자열을 감싸면 줄바꿈을 해도
# 모두 그대로 출력이 된다.
# 쌍따옴표 3개나 홀따옴표 3개로 감싸면 된다

# %%
long_char6
# Out:
# '따옴표 3개로 문자열을 감싸면 줄바꿈을 해도\n모두 그대로 출력이 된다.\n쌍따옴표 3개나 홀따옴표 3개로 감싸면 된다'

# %%
문자 덧셈+, 문자 반복*

# %%
d

# %%
문자변수1+문자변수2=문자가 합쳐짐

# %%
c+d

# %%
문자나 문자열을 반복하고 싶을때 : 문자변수*숫자

# %%
e*3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 e*3
#
# NameError: name 'e' is not defined

# %%
# 문자열은 순서가 있다.
#가장 앞 글자가 0번, 0번부터 순서대로 숫자가 증가함

# %%
길이를 재는 함수 len()
# Out:
#   Cell In[25], line 1
#     길이를 재는 함수 len()
#         ^
# SyntaxError: invalid syntax

# %%
len(long_char)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 len(long_char)
#
# NameError: name 'long_char' is not defined

# %%
* 인덱싱 : 변수명.[인덱스].
* 슬라이싱 : 변수명.[시작번호:끝번호]

# %% [markdown]
# * 파란색으로 표시가 떴을 때
# * m: 마크다운모드
# * y: 입력모드
# * shift+enter : 실행 후 다음 셀로 이동
