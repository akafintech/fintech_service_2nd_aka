# %% [markdown]
# * 국민은행 앱 사욛자 리뷰 데이터 JSON 파일을 읽어와서 csv 파일로 변환하기

# %%
import json
import pandas as pd

# %%
with open("./data/com_kbstar_kbbank.json", 'r', encoding="utf-8") as file :
    data = file.read()
print(data[:20])
# Out:
# [
#     {
#         "사용자

# %%
data[:100]
# Out:
# '[\n    {\n        "사용자": "박성진 (홀리진)",\n        "별점": "4",\n        "리뷰": "리브와 리브넥스트에서 사용했던 ATM입금 기능이 있으면'

# %%
reviews = json.loads(data)
len(reviews)
# Out:
# 2223

# %%
reviews[0]
# Out:
# {'사용자': '박성진 (홀리진)',
#  '별점': '4',
#  '리뷰': '리브와 리브넥스트에서 사용했던 ATM입금 기능이 있으면 좋겠습니다. 현금이나 실물 카드를 가지고 다니지 않게 되는 편리한 금융생활을 누릴 수 있었는데 리브넥스트의 종료로 더 이상 모바일에서는 ATM에서 현금 입금을 할 수 없게 됐습니다. 이 기능을 없애게 된 이유가 있나요? 출금 기능만 남았던데 입금 기능을 만들어주시면 좋겠습니다.',
#  '날짜': '2025년 3월 2일',
#  '개발자 응답': '고객님, 안녕하세요. 현재 KB스타뱅킹에서는 ATM입금 서비스를 제공하고 있지 않으나, 고객님께서 편리하게 이용하셨던 점이 충분히 이해되어 ATM입금 기능 도입 여부에 대해 검토해 보도록 하겠습니다. 다만, 새로운 서비스를 도입하기 위해서는 타행 시장조사, 요건 분석 및 개발 범위 등 검토되어야할 사항이 많아 다소 많은 시일이 소요될 수 있는 점 양해 부탁드립니다. 마지막으로 당행 자동화기기에서는 통장/카드없이 무통장 입금 서비스를 이용하실 수 있는 방법도 있으니 거래에 참고 부탁드리겠습니다.(*이용한도: 1회 50만원, 1일 100만원) 더욱 편리한 서비스를 제공하는 KB스타뱅킹이 되겠습니다. 감사합니다.'}

# %%
users=[]
points=[]
rev=[]
year_m=[]
recomd=[]

for i in reviews :
    users.append(i['사용자'])
    points.append(i['별점'])
    rev.append(i['리뷰'])
    year_m.append(i['날짜'])
    recomd.append(i['개발자 응답'])
    
review_info = dict(사용자=users, 별점=points, 리뷰=rev, 날짜=year_m, 개발자응답=recomd)
review_info
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 15
#      12     recomd.append(i['개발자 응답'])
#      14 review_info = dict(사용자=users, 별점=points, 리뷰=rev, 날짜=year_m, 개발자응답=recomd)
# ---> 15 review_info[:4]
#
# TypeError: unhashable type: 'slice'

# %%
df = pd.DataFrame(review_info)
df
# Out:
#                   사용자 별점                                                 리뷰  \
# 0           박성진 (홀리진)  4  리브와 리브넥스트에서 사용했던 ATM입금 기능이 있으면 좋겠습니다. 현금이나 실물 ...
# 1                 윤태경  5  KB스타뱅킹 입출금계좌를 가입한 후, 전반적으로 매우 만족스러운 경험을 했습니다. ...
# 2             tae tae  1  타 은행대비 증명서발급이 매우 불편하고 제한적임. 그리고 메뉴이동도 불편함. 뒤로가...
# 3                정다우니  5  설치 후 통장 개설 시 오류로 인해 종료가 됐었습니다. 하나하나 집중해서 잘했는데 ...
# 4                 우간능  1  왜 자꾸 앱 전용키보드를 쓸때 두개가 같이 눌리나요 그거땜에 로그인도 못하고 제대로...
# ...               ... ..                                                ...
# 2218              김하늘  5        평일 근무시간에 사진인증이 잘되는편 같습니다 업무시간 이외에도 잘되면 좋겠네요
# 2219          밝고긍정적인거  1  아니이봐요지금 타금융기관어플은 다되는데 이것만안된다고요 이것만.네트워크문제였었으면 ...
# 2220              정현우  5                       안내가 정확해서 따라가면 다 되어서 너무 편리합니다
# 2221               임겸  5                    어플 UI가 알아보기 쉽고 사용하기 너무 편리해서 좋아요
# 2222  Changwan “-” Yu  1  어플 문제 때문에 월세도 못 내게 생겼습니다. 와이파이가 매우 잘 작동하는 상황에서...
#
#                  날짜                                              개발자응답
# 0       2025년 3월 2일  고객님, 안녕하세요. 현재 KB스타뱅킹에서는 ATM입금 서비스를 제공하고 있지 않으...
# 1      2025년 1월 20일  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...
# 2      2025년 1월 14일  안녕하세요 고객님. KB스타뱅킹 이용에 불편을 드려 죄송합니다. 고객님의 의견을 증...
# 3      2025년 1월 25일  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...
# 4       2025년 2월 1일  고객님 안녕하세요. KB스타뱅킹 이용에 불편을 드려 진심으로 죄송합니다. 사용자암호...
# ...             ...                                                ...
# 2218   2025년 3월 11일  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...
# 2219  2024년 12월 26일  안녕하세요. KB스타뱅킹 이용에 불편을 드려 죄송합니다. 앱 구동이 원활하지 않을 ...
# 2220   2025년 3월 11일  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...
# 2221    2025년 3월 3일  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...
# 2222  2023년 10월 12일  고객님, 안녕하세요! KB스타뱅킹 이용에 불편을 드려 대단히 죄송합니다. 앱 이용 ...
#
# [2223 rows x 5 columns]

# %%
result={}
for key in reviews[0] :
    value_list = []
    for item in reviews[:2]:
        value_list.append(item[key])
    print(key, value_list)
    result[key] = value_list
# Out:
# 사용자 ['박성진 (홀리진)', '윤태경']
# 별점 ['4', '5']
# 리뷰 ['리브와 리브넥스트에서 사용했던 ATM입금 기능이 있으면 좋겠습니다. 현금이나 실물 카드를 가지고 다니지 않게 되는 편리한 금융생활을 누릴 수 있었는데 리브넥스트의 종료로 더 이상 모바일에서는 ATM에서 현금 입금을 할 수 없게 됐습니다. 이 기능을 없애게 된 이유가 있나요? 출금 기능만 남았던데 입금 기능을 만들어주시면 좋겠습니다.', 'KB스타뱅킹 입출금계좌를 가입한 후, 전반적으로 매우 만족스러운 경험을 했습니다. 가입 과정은 간편하고 빠르게 진행되었으며, 온라인으로 모든 절차를 처리할 수 있어 편리했습니다. 특히, 모바일 앱의 사용자 인터페이스가 직관적이어서 처음 사용하는 사람도 쉽게 이해할 수 있었습니다. 계좌 개설 후에는 다양한 금융 서비스가 제공되어 더욱 유용했습니다. 특히 실시간 거래 내역 확인과 간편한 송금 서비스가 매우 마음에 들었습니다. 또한, 다양한 금융 상품에 쉽게 접근할 수 있어 자산 관리를 할 때 큰 도움이 되었습니다. 고객 서비스도 만족스러웠습니다. 문의사항이 있을 때 신속하게 응대해 주었고, 필요한 정보도 쉽게 얻을 수 있었습니다. 보안 측면에서도 안심할 수 있었고, 다양한 인증 절차가 있어 개인 정보 보호에 대한 걱정이 줄어들었습니다. 종합적으로 KB스타뱅킹 입출금계좌는 편리함과 효율성을 모두 갖춘 서비스로, 앞으로도 지속적으로 이용할 계획입니다.']
# 날짜 ['2025년 3월 2일', '2025년 1월 20일']
# 개발자 응답 ['고객님, 안녕하세요. 현재 KB스타뱅킹에서는 ATM입금 서비스를 제공하고 있지 않으나, 고객님께서 편리하게 이용하셨던 점이 충분히 이해되어 ATM입금 기능 도입 여부에 대해 검토해 보도록 하겠습니다. 다만, 새로운 서비스를 도입하기 위해서는 타행 시장조사, 요건 분석 및 개발 범위 등 검토되어야할 사항이 많아 다소 많은 시일이 소요될 수 있는 점 양해 부탁드립니다. 마지막으로 당행 자동화기기에서는 통장/카드없이 무통장 입금 서비스를 이용하실 수 있는 방법도 있으니 거래에 참고 부탁드리겠습니다.(*이용한도: 1회 50만원, 1일 100만원) 더욱 편리한 서비스를 제공하는 KB스타뱅킹이 되겠습니다. 감사합니다.', "고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹은 고객님께서 항상 편리하게 사용하실 수 있도록 최선을 다하겠습니다! 앱 이용 중 개선사항이 있으시다면, [네이버 포스트 'KB스타뱅킹 앱리뷰' 고객의 소리] 또는 고객센터(1588-9999>0>3번)로 언제든 편하게 말씀해 주시기 바랍니다♥ 감사합니다!"]

# %% [markdown]
# * 풀이

# %%
result = {}
for key in reviews[0]:
    temp = []
    for review in reviews:
        temp.append(review[key])
    result[key] = temp
len(result['별점'])
# Out:
# 2223

# %%
df = pd.DataFrame(result)
df
# Out:
#                   사용자 별점                                                 리뷰  \
# 0           박성진 (홀리진)  4  리브와 리브넥스트에서 사용했던 ATM입금 기능이 있으면 좋겠습니다. 현금이나 실물 ...
# 1                 윤태경  5  KB스타뱅킹 입출금계좌를 가입한 후, 전반적으로 매우 만족스러운 경험을 했습니다. ...
# 2             tae tae  1  타 은행대비 증명서발급이 매우 불편하고 제한적임. 그리고 메뉴이동도 불편함. 뒤로가...
# 3                정다우니  5  설치 후 통장 개설 시 오류로 인해 종료가 됐었습니다. 하나하나 집중해서 잘했는데 ...
# 4                 우간능  1  왜 자꾸 앱 전용키보드를 쓸때 두개가 같이 눌리나요 그거땜에 로그인도 못하고 제대로...
# ...               ... ..                                                ...
# 2218              김하늘  5        평일 근무시간에 사진인증이 잘되는편 같습니다 업무시간 이외에도 잘되면 좋겠네요
# 2219          밝고긍정적인거  1  아니이봐요지금 타금융기관어플은 다되는데 이것만안된다고요 이것만.네트워크문제였었으면 ...
# 2220              정현우  5                       안내가 정확해서 따라가면 다 되어서 너무 편리합니다
# 2221               임겸  5                    어플 UI가 알아보기 쉽고 사용하기 너무 편리해서 좋아요
# 2222  Changwan “-” Yu  1  어플 문제 때문에 월세도 못 내게 생겼습니다. 와이파이가 매우 잘 작동하는 상황에서...
#
#                  날짜                                             개발자 응답
# 0       2025년 3월 2일  고객님, 안녕하세요. 현재 KB스타뱅킹에서는 ATM입금 서비스를 제공하고 있지 않으...
# 1      2025년 1월 20일  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...
# 2      2025년 1월 14일  안녕하세요 고객님. KB스타뱅킹 이용에 불편을 드려 죄송합니다. 고객님의 의견을 증...
# 3      2025년 1월 25일  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...
# 4       2025년 2월 1일  고객님 안녕하세요. KB스타뱅킹 이용에 불편을 드려 진심으로 죄송합니다. 사용자암호...
# ...             ...                                                ...
# 2218   2025년 3월 11일  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...
# 2219  2024년 12월 26일  안녕하세요. KB스타뱅킹 이용에 불편을 드려 죄송합니다. 앱 구동이 원활하지 않을 ...
# 2220   2025년 3월 11일  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...
# 2221    2025년 3월 3일  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...
# 2222  2023년 10월 12일  고객님, 안녕하세요! KB스타뱅킹 이용에 불편을 드려 대단히 죄송합니다. 앱 이용 ...
#
# [2223 rows x 5 columns]

# %% [markdown]
# * 별점은 숫자로 변환해서 넣기, 나머지 특문은 제거

# %%
result = {}
for key in reviews[0]:
    temp = []
    for review in reviews:
        if key == '별점':
            temp.append(int(review[key]))
        else :
            temp.append(review[key].apepnd)
        temp.append(review[key])
    result[key] = temp
len(result['별점'])

# %%
result2 = {}
for review in reviews[:2]:
    for key, value in review.items():
        result2.setdefault(key, []).append(value)
result2_df=pd.DataFrame(result2)
result2_df
# Out:
#          사용자 별점                                                 리뷰  \
# 0  박성진 (홀리진)  4  리브와 리브넥스트에서 사용했던 ATM입금 기능이 있으면 좋겠습니다. 현금이나 실물 ...
# 1        윤태경  5  KB스타뱅킹 입출금계좌를 가입한 후, 전반적으로 매우 만족스러운 경험을 했습니다. ...
#
#              날짜                                             개발자 응답
# 0   2025년 3월 2일  고객님, 안녕하세요. 현재 KB스타뱅킹에서는 ATM입금 서비스를 제공하고 있지 않으...
# 1  2025년 1월 20일  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...

# %%
import json

# %%
with open ("./data/전국치킨집리스트.json",  'r', encoding="utf-8") as file3 :
    chicken = json.load(file3)
print(type(chicken))
# Out:
# <class 'list'>

# %%
len(chicken)
# Out:
# 37

# %%
c_item=chicken[0]['body']['items']
c_item[0]
# Out:
# {'bizesId': '10027626',
#  'bizesNm': '장모님치킨가창점',
#  'brchNm': '가창점',
#  'indsLclsCd': 'Q',
#  'indsLclsNm': '음식',
#  'indsMclsCd': 'Q05',
#  'indsMclsNm': '닭/오리요리',
#  'indsSclsCd': 'Q05A08',
#  'indsSclsNm': '후라이드/양념치킨',
#  'ksicCd': 'I56193',
#  'ksicNm': '치킨 전문점',
#  'ctprvnCd': '27',
#  'ctprvnNm': '대구광역시',
#  'signguCd': '27710',
#  'signguNm': '달성군',
#  'adongCd': '2771031000',
#  'adongNm': '가창면',
#  'ldongCd': '2771031024',
#  'ldongNm': '가창면',
#  'lnoCd': '2771031024101200001',
#  'plotSctCd': '1',
#  'plotSctNm': '대지',
#  'lnoMnno': 120,
#  'lnoSlno': 1,
#  'lnoAdr': '대구광역시 달성군 가창면 냉천리 120-1',
#  'rdnmCd': '277103148001',
#  'rdnm': '대구광역시 달성군 가창면 가창동로',
#  'bldMnno': 6,
#  'bldSlno': '',
#  'bldMngNo': '2771031024101200004036858',
#  'bldNm': '',
#  'rdnmAdr': '대구광역시 달성군 가창면 가창동로 6',
#  'oldZipcd': '711861',
#  'newZipcd': '42938',
#  'dongNo': '',
#  'flrNo': '1',
#  'hoNo': '',
#  'lon': 128.644458591419,
#  'lat': 35.7826625402814}

# %%
result2={}
for key in c_item[0]:
    v_list=[]
    for i in c_item[:2]:
        v_list.append(i[key])
    print(key, v_list)
    result2[key]=v_list
# Out:
# header [{'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'columns': ['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드', '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드', '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', 'PNU코드', '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지', '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보', '호정보', '경도', '위도'], 'stdrYm': '202206', 'resultCode': '00', 'resultMsg': 'NORMAL SERVICE'}, {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'columns': ['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드', '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드', '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', 'PNU코드', '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지', '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보', '호정보', '경도', '위도'], 'stdrYm': '202206', 'resultCode': '00', 'resultMsg': 'NORMAL SERVICE'}]
# body [{'items': [{'bizesId': '10027626', 'bizesNm': '장모님치킨가창점', 'brchNm': '가창점', 'indsLclsCd': 'Q', 'indsLclsNm': '음식', 'indsMclsCd': 'Q05', 'indsMclsNm': '닭/오리요리', 'indsSclsCd': 'Q05A08', 'indsSclsNm': '후라이드/양념치킨', 'ksicCd': 'I56193', 'ksicNm': '치킨 전문점', 'ctprvnCd': '27', 'ctprvnNm': '대구광역시', 'signguCd': '27710', 'signguNm': '달성군', 'adongCd': '2771031000', 'adongNm': '가창면', 'ldongCd': '2771031024', 'ldongNm': '가창면', 'lnoCd': '2771031024101200001', 'plotSctCd': '1', 'plotSctNm': '대지', 'lnoMnno': 120, 'lnoSlno': 1, 'lnoAdr': '대구광역시 달성군 가창면 냉천리 120-1', 'rdnmCd': '277103148001', 'rdnm': '대구광역시 달성군 가창면 가창동로', 'bldMnno': 6, 'bldSlno': '', 'bldMngNo': '2771031024101200004036858', 'bldNm': '', 'rdnmAdr': '대구광역시 달성군 가창면 가창동로 6', 'oldZipcd': '711861', 'newZipcd': '42938', 'dongNo': '', 'flrNo': '1', 'hoNo': '', 'lon': 128.644458591419, 'lat': 35.7826625402814}, {'bizesId': '10098244', 'bizesNm': '짱구피자치킨', 'brchNm': '', 'indsLclsCd': 'Q', 'indsLclsNm': '음식', 'indsMclsCd': 'Q05', 'indsMclsNm': '닭/오리요리', 'indsSclsCd': 'Q05A08', 'indsSclsNm': '후라이드/양념치킨', 'ksicCd': 'I56193', 'ksicNm': '치킨 전문점', 'ctprvnCd': '41', 'ctprvnNm': '경기도', 'signguCd': '41250', 'signguNm': '동두천시', 'adongCd': '4125056500', 'adongNm': '불현동', 'ldongCd': '4125010300', 'ldongNm': '생연동', 'lnoCd': '4125010300102680011', 'plotSctCd': '1', 'plotSctNm': '대지', 'lnoMnno': 268, 'lnoSlno': 11, 'lnoAdr': '경기도 동두천시 생연동 268-11', 'rdnmCd': '412503189006', 'rdnm': '경기도 동두천시 못골로', 'bldMnno': 30, 'bldSlno': '', 'bldMngNo': '4125010300102680011008557', 'bldNm': '', 'rdnmAdr': '경기도 동두천시 못골로 30', 'oldZipcd': '483030', 'newZipcd': '11320', 'dongNo': '', 'flrNo': '', 'hoNo': '', 'lon': 127.06590346074, 'lat': 37.9012616518346}, {'bizesId': '10099459', 'bizesNm': '쭈노치킨', 'brchNm': '', 'indsLclsCd': 'Q', 'indsLclsNm': '음식', 'indsMclsCd': 'Q05', 'indsMclsNm': '닭/오리요리', 'indsSclsCd': 'Q05A08', 'indsSclsNm': '후라이드/양념치킨', 'ksicCd': 'I56193', 'ksicNm': '치킨 전문점', 'ctprvnCd': '41', 'ctprvnNm': '경기도', 'signguCd': '41570', 'signguNm': '김포시', 'adongCd': '4157025300', 'adongNm': '고촌읍', 'ldongCd': '4157025324', 'ldongNm': '고촌읍', 'lnoCd': '4157025324105380008', 'plotSctCd': '1', 'plotSctNm': '대지', 'lnoMnno': 538, 'lnoSlno': 8, 'lnoAdr': '경기도 김포시 고촌읍 신곡리 538-8', 'rdnmCd': '415704427512', 'rdnm': '경기도 김포시 고촌읍 장차로13번길', 'bldMnno': 18, 'bldSlno': '', 'bldMngNo': '4157025324105380008019970', 'bldNm': '', 'rdnmAdr': '경기도 김포시 고촌읍 장차로13번길 18', 'oldZipcd': '415811', 'newZipcd': '10126', 'dongNo': '', 'flrNo': '1', 'hoNo': '', 'lon': 126.769859060814, 'lat': 37.6037515030602}, {'bizesId': '10136167', 'bizesNm': '치킨뱅이', 'brchNm': '', 'indsLclsCd': 'Q', 'indsLclsNm': '음식', 'indsMclsCd': 'Q05', 'indsMclsNm': '닭/오리요리', 'indsSclsCd': 'Q05A08', 'indsSclsNm': '후라이드/양념치킨', 'ksicCd': 'I56193', 'ksicNm': '치킨 전문점', 'ctprvnCd': '42', 'ctprvnNm': '강원도', 'signguCd': '42130', 'signguNm': '원주시', 'adongCd': '4213059000', 'adongNm': '단계동', 'ldongCd': '4213011000', 'ldongNm': '단계동', 'lnoCd': '4213011000108300006', 'plotSctCd': '1', 'plotSctNm': '대지', 'lnoMnno': 830, 'lnoSlno': 6, 'lnoAdr': '강원도 원주시 단계동 830-6', 'rdnmCd': '421304457083', 'rdnm': '강원도 원주시 금불3길', 'bldMnno': 5, 'bldSlno': '', 'bldMngNo': '4213011000108300006022278', 'bldNm': '', 'rdnmAdr': '강원도 원주시 금불3길 5', 'oldZipcd': '220938', 'newZipcd': '26423', 'dongNo': '', 'flrNo': '1', 'hoNo': '', 'lon': 127.932025388709, 'lat': 37.3483579547022}, {'bizesId': '10136346', 'bizesNm': '치킨월드율량점', 'brchNm': '율량점', 'indsLclsCd': 'Q', 'indsLclsNm': '음식', 'indsMclsCd': 'Q05', 'indsMclsNm': '닭/오리요리', 'indsSclsCd': 'Q05A08', 'indsSclsNm': '후라이드/양념치킨', 'ksicCd': 'I56193', 'ksicNm': '치킨 전문점', 'ctprvnCd': '43', 'ctprvnNm': '충청북도', 'signguCd': '43114', 'signguNm': '청주시 청원구', 'adongCd': '4311454000', 'adongNm': '율량.사천동', 'ldongCd': '4311410300', 'ldongNm': '율량동', 'lnoCd': '4311410300108060000', 'plotSctCd': '1', 'plotSctNm': '대지', 'lnoMnno': 806, 'lnoSlno': '', 'lnoAdr': '충청북도 청주시 청원구 율량동 806', 'rdnmCd': '431144508043', 'rdnm': '충청북도 청주시 청원구 공항로138번길', 'bldMnno': 53, 'bldSlno': '', 'bldMngNo': '4 ...

# %%
chikkey={}
for key in chicken[0]:
    temp2 = []
    for dicts in chicken:
        temp2.append(dicts[key])
    chikkey[key] = temp2
len(chikkey['flrNo'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[86], line 7
#       5         temp2.append(dicts[key])
#       6     chikkey[key] = temp2
# ----> 7 len(chikkey['flrNo'])
#
# KeyError: 'flrNo'

# %%
print(chikkey.values())[0]
# Out:
# dict_values([[{'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'columns': ['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드', '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드', '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', 'PNU코드', '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지', '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보', '호정보', '경도', '위도'], 'stdrYm': '202206', 'resultCode': '00', 'resultMsg': 'NORMAL SERVICE'}], [{'items': [{'bizesId': '10027626', 'bizesNm': '장모님치킨가창점', 'brchNm': '가창점', 'indsLclsCd': 'Q', 'indsLclsNm': '음식', 'indsMclsCd': 'Q05', 'indsMclsNm': '닭/오리요리', 'indsSclsCd': 'Q05A08', 'indsSclsNm': '후라이드/양념치킨', 'ksicCd': 'I56193', 'ksicNm': '치킨 전문점', 'ctprvnCd': '27', 'ctprvnNm': '대구광역시', 'signguCd': '27710', 'signguNm': '달성군', 'adongCd': '2771031000', 'adongNm': '가창면', 'ldongCd': '2771031024', 'ldongNm': '가창면', 'lnoCd': '2771031024101200001', 'plotSctCd': '1', 'plotSctNm': '대지', 'lnoMnno': 120, 'lnoSlno': 1, 'lnoAdr': '대구광역시 달성군 가창면 냉천리 120-1', 'rdnmCd': '277103148001', 'rdnm': '대구광역시 달성군 가창면 가창동로', 'bldMnno': 6, 'bldSlno': '', 'bldMngNo': '2771031024101200004036858', 'bldNm': '', 'rdnmAdr': '대구광역시 달성군 가창면 가창동로 6', 'oldZipcd': '711861', 'newZipcd': '42938', 'dongNo': '', 'flrNo': '1', 'hoNo': '', 'lon': 128.644458591419, 'lat': 35.7826625402814}, {'bizesId': '10098244', 'bizesNm': '짱구피자치킨', 'brchNm': '', 'indsLclsCd': 'Q', 'indsLclsNm': '음식', 'indsMclsCd': 'Q05', 'indsMclsNm': '닭/오리요리', 'indsSclsCd': 'Q05A08', 'indsSclsNm': '후라이드/양념치킨', 'ksicCd': 'I56193', 'ksicNm': '치킨 전문점', 'ctprvnCd': '41', 'ctprvnNm': '경기도', 'signguCd': '41250', 'signguNm': '동두천시', 'adongCd': '4125056500', 'adongNm': '불현동', 'ldongCd': '4125010300', 'ldongNm': '생연동', 'lnoCd': '4125010300102680011', 'plotSctCd': '1', 'plotSctNm': '대지', 'lnoMnno': 268, 'lnoSlno': 11, 'lnoAdr': '경기도 동두천시 생연동 268-11', 'rdnmCd': '412503189006', 'rdnm': '경기도 동두천시 못골로', 'bldMnno': 30, 'bldSlno': '', 'bldMngNo': '4125010300102680011008557', 'bldNm': '', 'rdnmAdr': '경기도 동두천시 못골로 30', 'oldZipcd': '483030', 'newZipcd': '11320', 'dongNo': '', 'flrNo': '', 'hoNo': '', 'lon': 127.06590346074, 'lat': 37.9012616518346}, {'bizesId': '10099459', 'bizesNm': '쭈노치킨', 'brchNm': '', 'indsLclsCd': 'Q', 'indsLclsNm': '음식', 'indsMclsCd': 'Q05', 'indsMclsNm': '닭/오리요리', 'indsSclsCd': 'Q05A08', 'indsSclsNm': '후라이드/양념치킨', 'ksicCd': 'I56193', 'ksicNm': '치킨 전문점', 'ctprvnCd': '41', 'ctprvnNm': '경기도', 'signguCd': '41570', 'signguNm': '김포시', 'adongCd': '4157025300', 'adongNm': '고촌읍', 'ldongCd': '4157025324', 'ldongNm': '고촌읍', 'lnoCd': '4157025324105380008', 'plotSctCd': '1', 'plotSctNm': '대지', 'lnoMnno': 538, 'lnoSlno': 8, 'lnoAdr': '경기도 김포시 고촌읍 신곡리 538-8', 'rdnmCd': '415704427512', 'rdnm': '경기도 김포시 고촌읍 장차로13번길', 'bldMnno': 18, 'bldSlno': '', 'bldMngNo': '4157025324105380008019970', 'bldNm': '', 'rdnmAdr': '경기도 김포시 고촌읍 장차로13번길 18', 'oldZipcd': '415811', 'newZipcd': '10126', 'dongNo': '', 'flrNo': '1', 'hoNo': '', 'lon': 126.769859060814, 'lat': 37.6037515030602}, {'bizesId': '10136167', 'bizesNm': '치킨뱅이', 'brchNm': '', 'indsLclsCd': 'Q', 'indsLclsNm': '음식', 'indsMclsCd': 'Q05', 'indsMclsNm': '닭/오리요리', 'indsSclsCd': 'Q05A08', 'indsSclsNm': '후라이드/양념치킨', 'ksicCd': 'I56193', 'ksicNm': '치킨 전문점', 'ctprvnCd': '42', 'ctprvnNm': '강원도', 'signguCd': '42130', 'signguNm': '원주시', 'adongCd': '4213059000', 'adongNm': '단계동', 'ldongCd': '4213011000', 'ldongNm': '단계동', 'lnoCd': '4213011000108300006', 'plotSctCd': '1', 'plotSctNm': '대지', 'lnoMnno': 830, 'lnoSlno': 6, 'lnoAdr': '강원도 원주시 단계동 830-6', 'rdnmCd': '421304457083', 'rdnm': '강원도 원주시 금불3길', 'bldMnno': 5, 'bldSlno': '', 'bldMngNo': '4213011000108300006022278', 'bldNm': '', 'rdnmAdr': '강원도 원주시 금불3길 5', 'oldZipcd': '220938', 'newZipcd': '26423', 'dongNo': '', 'flrNo': '1', 'hoNo': '', 'lon': 127.932025388709, 'lat': 37.3483579547022}, {'bizesId': '10136346', 'bizesNm': '치킨월드율량점', 'brchNm': '율량점', 'indsLclsCd': 'Q', 'indsLclsNm': '음식', 'indsMclsCd': 'Q05', 'indsMclsNm': '닭/오리요리', 'indsScl ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 print(chikkey.values())[0]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
result_ch = pd.DataFrame(chikkey)
result_ch
# Out:
#                                                header  \
# 0   {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 1   {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 2   {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 3   {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 4   {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 5   {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 6   {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 7   {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 8   {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 9   {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 10  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 11  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 12  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 13  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 14  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 15  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 16  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 17  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 18  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 19  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 20  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 21  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 22  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 23  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 24  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 25  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 26  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 27  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 28  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 29  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 30  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 31  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 32  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 33  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 34  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 35  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
# 36  {'description': '소상공인시장진흥공단 주요상권내 상가업소정보', 'co...
#
#                                                  body
# 0   {'items': [{'bizesId': '10027626', 'bizesNm': ...
# 1   {'items': [{'bizesId': '11927910', 'bizesNm': ...
# 2   {'items': [{'bizesId': '12078226', 'bizesNm': ...
# 3   {'items': [{'bizesId': '12448225', 'bizesNm': ...
# 4   {'items': [{'bizesId': '12601898', 'bizesNm': ...
# 5   {'items': [{'bizesId': '15841722', 'bizesNm': ...
# 6   {'items': [{'bizesId': '16099079', 'bizesNm': ...
# 7   {'items': [{'bizesId': '16280562', 'bizesNm': ...
# 8   {'items': [{'bizesId': '16484714', 'bizesNm': ...
# 9   {'items': [{'bizesId': '16604739', 'bizesNm': ...
# 10  {'items': [{'bizesId': '16728435', 'bizesNm': ...
# 11  {'items': [{'bizesId': '17014298', 'bizesNm': ...
# 12  {'items': [{'bizesId': '17142954', 'bizesNm': ...
# 13  {'items': [{'bizesId': '17430609', 'bizesNm': ...
# 14  {'items': [{'bizesId': '17504547', 'bizesNm': ...
# 15  {'items': [{'bizesId': '17616920', 'bizesNm': ...
# 16  {'items': [{'bizesId': '17847228', 'bizesNm': ...
# 17  {'items': [{'bizesId': '17915858', 'bizesNm': ...
# 18  {'items': [{'bizesId': '18114669', 'bizesNm': ...
# 19  {'items': [{'bizesId': '18354009', 'bizesNm': ...
# 20  {'items': [{'bizesId': '19991844', 'bizesNm': ...
# 21  {'items': [{'bizesId': '20158282', 'bizesNm': ...
# 22  {'items': [{'bizesId': '20304765', 'bizesNm': ...
# 23  {'items': [{'bizesId': '20450480', 'bizesNm': ...
# 24  {'items': [{'bizesId': '20609325', 'bizesNm': ...
# 25  {'items': [{'bizesId': '21867919', 'bizesNm': ...
# 26  {'items': [{'bizesId': '22092363', 'bizesNm': ...
# 27  {'items': [{'bizesId': '23180454', 'bizesNm': ...
# 28  {'items': [{'bizesId': '23395927', 'bizesNm': ...
# 29  {'items': [{'bizesId': '25259031', 'bizesNm': ...
# 30  {'items': [{'bizesId': '25551235', 'bizesNm': ...
# 31  {'items': [{'bizesId': '25789400', 'bizesNm': ...
# 32  {'items': [{'bizesId': '26069091', 'bizesNm': ...
# 33  {'items': [{'bizesId': '26205307', 'bizesNm': ...
# 34  {'items': [{'bizesId': '26205307', 'bizesNm': ...
# 35  {'items': [{'bizesId': '28488294', 'bizesNm': ...
# 36  {'items': [{'bizesId': '9148230', 'bizesNm': '...
