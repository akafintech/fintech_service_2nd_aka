# %% [markdown]
# # 모듈 사용하기
# * 누군가 미리 사용하기 편하게 만들어 놓은 함수, 클래스
# * import 명령을 통해 프로그램 가장 위에서 모듈을 불러와 사용할 수 있음
# * 모듈에 너무 많은 기능이 있는 경우 from 모둘명 import 함수/메서드명 형식으로 일부 기능만 불러올 수 있음
# * 모듈은 사용자가 직접 만들 수 있음
# * 모듈을 불러올 때 실행하는 파일과 같은 위치에 있어야 함

# %% [markdown]
# # datetime 모듈 사용하기

# %%
from datetime import datetime

# %%
now = datetime.now()

# %%
now.year
# Out:
# 2025

# %%
now.minute
# Out:
# 29

# %% [markdown]
# * 시간을 포멧에 맞춰 출력하기

# %%
now.strftime("%Y.%m.%d %H:%M:%S")
# Out:
# '2025.03.28 16:29:24'

# %% [markdown]
# # OS 모듈

# %%
import os

# %%
# 내가 사용하는 컴퓨터의 기본정보 출력하기
print("현재 운영체제:", os.name)
print("현재 사용하는 폴더:", os.getcwd())
print("현재 폴더 내부의 파일 리스트", os.listdir())
# Out:
# 현재 운영체제: nt
# 현재 사용하는 폴더: C:\fintech\03PYTHON
# ...

# %%
file=[]
for file_name in os.listdir():
#     print(i):
    if file_name[-3:] == "txt":
        print(i)
        with open(file_name, encoding="utf-8") as file:
            data = file.read()
            files.append(data)
# Out:
# 호텔평점.csv
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 8
#       6 with open(file_name, encoding="utf-8") as file:
#       7     data = file.read()
# ----> 8     files.append(data)
#
# NameError: name 'files' is not defined

# %%
# 현재위치에서 폴더 만들기
os.mkdir("testdir")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[36], line 2
#       1 # 현재위치에서 폴더 만들기
# ----> 2 os.mkdir("testdir")
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: 'testdir'

# %%
# 현재위치에서 폴더 삭제하기
os.rmdir("testdir")

# %%
# cmd 명령어 실행하기
os.system("dir")
# Out:
# 0

# %%
# 파일을 생성하고 파일이름 변경하기
with open("original.txt", "w") as file:
    file.write("안녕하세요")

# %%
os.rename("original.txt", "new.txt")

# %%
# 폴더가 있는지 확인하고 없으면 폴더 생성하기
if not os.path.exists("./testdir"):
    os.mkdir("testdir")
else:
    print("testdir이 이미 있습니다.")
# Out:
# testdir이 이미 있습니다.

# %%
# 환경변수에 변수와 값 추가하기
os.environ['key'] = "value"

# %%
print(os.environ.get('key'))
# Out:
# value

# %%
from myfunc import *

# %%
add(3,4)
# Out:
# 7

# %%
roy= Cal(3,4)

# %%
roy.add()
# Out:
# 7

# %%
roy.sub()
# Out:
# -1
