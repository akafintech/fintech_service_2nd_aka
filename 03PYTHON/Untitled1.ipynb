# %%
courses=dict(zip(['programming','design'],
             [{'python': 50, 'java': 30, 'Cpp': 20},{'Photoshop': 25, 'Illustrator': 15}]))
courses
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 20},
#  'design': {'Photoshop': 25, 'Illustrator': 15}}

# %%
courses.values()
# Out:
# dict_values([{'python': 50, 'java': 30, 'Cpp': 20}, {'Photoshop': 25, 'Illustrator': 15}])
