# %%
import time

# %%
while True:
    print("A")
    time.sleep(0.2)
# Out:
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 while True:
#       2     print("A")
# ----> 3     time.sleep(0.2)
#
# KeyboardInterrupt:
