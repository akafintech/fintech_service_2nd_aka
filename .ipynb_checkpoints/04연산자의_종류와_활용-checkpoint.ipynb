# %% [markdown]
# # 연산자의 종류
# * 산술, 할당, 비교, 논리, 식별, 멤버

# %% [markdown]
# # 산술연산자 + , -, *, /, %, //, **

# %%
1+1
# Out:
# 2

# %%
2+3.1
# Out:
# 5.1

# %%
3-4
# Out:
# -1

# %%
5*3
# Out:
# 15

# %%
5/3
# Out:
# 1.6666666666666667

# %%
4/2
# Out:
# 2.0

# %% [markdown]
# %는 나머지를 구하는 연산자(%2로 0이면 짝수 1이면 홀수)

# %%
3%2
# Out:
# 1

# %% [markdown]
# %는 나머지를 구하는 연산자

# %%
4%2
# Out:
# 0

# %%
15%2
# Out:
# 1

# %% [markdown]
# // 몫만 구하는 연산자

# %%
7//3
# Out:
# 2

# %% [markdown]
# ** 제곱

# %%
2**3
# Out:
# 8

# %% [markdown]
# # 할당연산자
# * =, +=, -=, *=, /+, %=
