# %%
# pip install google-play-scraper
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine, text
import pymysql
pymysql.install_as_MySQLdb()

# %%
import pandas as pd

# %%
from google_play_scraper import app

result = app(
    'viva.republica.toss',
    lang='ko', # defaults to 'en'
    country='kr' # defaults to 'us'
)

# %%
result
# Out:
# {'title': '토스',
# ...

# %%
import time

# %%
from google_play_scraper import Sort, reviews

result_all = []
for item in range(95):
    result, continuation_token = reviews(
        'viva.republica.toss',
        lang='ko', # defaults to 'en'
        country='kr', # defaults to 'us'
        sort=Sort.NEWEST, # defaults to Sort.NEWEST
        count=100) # defaults to 100
    result_all.extend(result)
    time.sleep(3)
    print(f"{item+1}/95 진행중", end="\r")
#     filter_score_with=5 # defaults to None(means all score)


# If you pass `continuation_token` as an argument to the reviews function at this point,
# it will crawl the items after 3 review items.

# result, _ = reviews(
#     'viva.republica.toss',
#     continuation_token=continuation_token # defaults to None(load from the beginning)
# )
# Out:
# 95/95 진행중

# %%
result_all[0]
# Out:
# {'reviewId': 'bffb6c5f-326f-4304-876c-374abdb10569',
#  'userName': '정보영',
#  'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJwd5fd3Vo405YYYsEemcH7EhevPwx18h_Rlc_Vr893Xuz9ng=mo',
#  'content': '자주쓰는계좌 업데이트 되었던데 이게 뭔가요.... 전처럼 사용자가 알아서 설정하게 원상복구 시켜주세요',
#  'score': 1,
#  'thumbsUpCount': 0,
#  'reviewCreatedVersion': '5.204.0',
#  'at': datetime.datetime(2025, 4, 10, 16, 16, 24),
#  'replyContent': '안녕하세요. 정보영 님, 토스팀입니다. 서비스 변경으로 인해 불편을 드린 것 같아 마음이 무겁습니다. 말씀주신 부분은 현재 점진적으로 모든 고객님들 대상으로 변경이 될 예정으로 이전 홈 화면으로의 변경은 어려운 점 너그러운 마음으로 양해 부탁드립니다. 귀한 시간 내어 전달해주신만큼 담당부서로 전달 될 수 있도록 하겠으며, 더 나은 서비스를 제공 위해 노력하겠습니다. 보다 자세한 확인 및 안내를 위해 24시간 운영되는 카카오톡(@toss) 또는 고객센터 1599-4905 로 편하실 때 문의 부탁 드려도 될까요? 일부 안내의 경우 리뷰를 통한 즉각적인 안내가 어려울 수 있는 점 양해 부탁 드립니다. 감사합니다.',
#  'repliedAt': datetime.datetime(2025, 4, 11, 3, 52, 35),
#  'appVersion': '5.204.0'}

# %%
reviews = pd.DataFrame(result_all)

# %%
df_rev = reviews[['at','userName','score','content','replyContent']]
df_rev.columns = ['날짜','유저명','평점','리뷰','답변']
df_rev.head()
# Out:
#                    날짜    유저명  평점  \
# 0 2025-04-10 16:16:24    정보영   1
# 1 2025-04-10 16:13:44  내가왕이다   3
# 2 2025-04-10 15:57:08    유승민   1
# 3 2025-04-10 13:20:36   호두파이   4
# 4 2025-04-10 12:33:06   _7타홍   1
#
#                                                   리뷰  \
# 0  자주쓰는계좌 업데이트 되었던데 이게 뭔가요.... 전처럼 사용자가 알아서 설정하게 ...
# 1  요 며칠 토스 친구가 안뜨네요. 저만 안뜨는게 아니고 주변에 몇 몇도 안뜬대요. 뜨...
# 2                                     카드 충전이 안되는데 무슨
# 3  다른건 다 좋은데 방금 두더지 잡기 이벤트 참여를 하려고 하니 비정상적인? 참여라고...
# 4  이벤트를 만들어놓고 참여하게 유도했지만 아무것도 하지 않음에도 부정행위 감지로 참여...
#
#                                                   답변
# 0  안녕하세요. 정보영 님, 토스팀입니다. 서비스 변경으로 인해 불편을 드린 것 같아 ...
# 1  안녕하세요. 내가왕이다 님, 토스팀입니다. 1일 이내 상대를 만나 클릭한 기록이 있...
# 2  안녕하세요. 유승민 님, 토스팀입니다. 남겨주신 내용만으로는 정확한 확인이 어려운 ...
# 3  안녕하세요, 고객님. 토스뱅크 고객센터 입니다. 두더지게임은 여러 고객님에게 혜택과...
# 4  안녕하세요, 고객님. 토스뱅크 고객센터 입니다. 두더지게임은 여러 고객님에게 혜택과...

# %%
type(df_rev)
# Out:
# pandas.core.frame.DataFrame

# %%
engine = create_engine("mysql+pymysql://root:1234@localhost:3306/toss_review")
conn = engine.connect()

# %%
df_rev.to_sql("reviews_toss", con=conn, if_exists='replace', index=False)
conn.close()

# %%
a = driver.find_element(By.CSS_SELECTOR, "div.ocpBU div.ras4vb > div").get_attribute("innerHTML")
type(a)
# Out:
# str

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import pandas as pd
from io import StringIO
import datetime
today = datetime.datetime.now()
today.year
today.month
today.day

options = Options()
options.add_experimental_option("detach", True)
options.add_argument("start-maximized")
options.add_argument("Chrome/135.0.0.0")
options.add_argument("lang=ko_KR")
# 웹브라우저 창 띄우지 않고 실행은 되게 하는 방법
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")


driver = webdriver.Chrome(
    service=Service(ChromeDriverManager().install()),
    options=options
    )

url = "https://play.google.com/store/apps/details?id=viva.republica.toss&hl=ko"
driver.get(url)
