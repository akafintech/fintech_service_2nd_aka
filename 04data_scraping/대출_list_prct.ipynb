# %%
import os
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
url = "https://apis.data.go.kr/1160100/service/GetSmallLoanFinanceInstituteInfoService/getOrdinaryFinanceInfo"
ServiceKey = "9t7REJxyasIgObYHfyb5IVl89Ya4YjIgK5dUjgd7%2Fi3BSX61mJ9Kr9rOY3x4hzH5bg5oJP8r%2BOytZGorS2lwOw%3D%3D"
ServiceKey_d = "9t7REJxyasIgObYHfyb5IVl89Ya4YjIgK5dUjgd7/i3BSX61mJ9Kr9rOY3x4hzH5bg5oJP8r+OytZGorS2lwOw=="
payload = {"serviceKey" : ServiceKey_d,
           "pageNo": 1,
           "numOfRows": 1,
           "resultType" : "xml"}

r2 = requests.get(url, params=payload)
print(r2, end = "\r")
print(r2.status_code, end = "\r")
f_response=r2.text
f_response
# Out:
# 200
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?>\n<response>\n    <header>\n        <resultCode>00</resultCode>\n        <resultMsg>NORMAL SERVICE.</resultMsg>\n    </header>\n    <body>\n        <numOfRows>1</numOfRows>\n        <pageNo>1</pageNo>\n        <totalCount>4741</totalCount>\n        <items>\n            <item>\n                <basYm>202503</basYm>\n                <snq>1</snq>\n                <finPrdNm>새희망홀씨Ⅱ</finPrdNm>\n                <lnLmt>3500만원</lnLmt>\n                <irtCtg>변동금리</irtCtg>\n                <irt>은행별 상이</irt>\n                <maxTotLnTrm>은행별 상이</maxTotLnTrm>\n                <maxDfrmTrm>-</maxDfrmTrm>\n                <maxRdptTrm>-</maxRdptTrm>\n                <rdptMthd>원(리)금균등분할상환</rdptMthd>\n                <usge>생계</usge>\n                <trgt>근로자</trgt>\n                <instCtg>시중은행</instCtg>\n                <ofrInstNm>14개 취급은행</ofrInstNm>\n                <rsdAreaPamtEqltIstm>전국</rsdAreaPamtEqltIstm>\n                <suprTgtDtlCond>연소득 4천만원 이하 (개인신용평점 하위 100분의 20*이하는 5천만원 이하) *23년 4월 기준 NICE 749점, KCB 700점 이하</suprTgtDtlCond>\n                <age>없음</age>\n                <incm>연소득 4천만원 이하 (개인신용평점 하위 100분의 20*이하는 5천만원 이하)</incm>\n                <rsdArea>-</rsdArea>\n                <crdtSc>신용평가회사의 개인신용평점이 하위 100분의 20에 해당하는자</crdtSc>\n                <anin>-</anin>\n                <housHoldCnt>-</housHoldCnt>\n                <housAr>-</housAr>\n                <lnTgtHous>-</lnTgtHous>\n                <rfrcCnpl>취급은행 콜센터, 서민금융콜센터 (국번없이)1397</rfrcCnpl>\n                <grnInst>-</grnInst>\n                <jnMthd>14개 취급은행 신청방법 문의</jnMthd>\n                <rpymdCfe>-</rpymdCfe>\n                <lnIcdcst>-</lnIcdcst>\n                <ovItrYr>-</ovItrYr>\n                <prftAddIrtCond>성실상환자, 사회적 취약계층(기초생활수급권자, 한부모가정, 다자녀가정, 다문화가정, 만 60세 이상 부모부양자, 청년층(만 29세 이하), 고령자(만 65세 이상), 장애인 등), 공신력 있는 금융교육기관에서 금융교육을 이수한 자에 대해 금리우대 (은행별 자율 결정)</prftAddIrtCond>\n                <etcRefSbjc>-</etcRefSbjc>\n                <hdlInst>취급 은행(14개)</hdlInst>\n                <cnpl>취급은행 콜센터, 서민금융콜센터 (국번없이)1397</cnpl>\n                <rltSite>취급은행 홈페이지</rltSite>\n                <tgtFltr>근로자</tgtFltr>\n                <hdlInstDtlVw>취급은행(국민, 신한, 우리, 기업, KEB하나, SC, 농협, 수협, 경남, 광주, 대구, 부산, 전북, 제주)</hdlInstDtlVw>\n                <prdExisYn>Y</prdExisYn>\n                <cv19Rfrc>-</cv19Rfrc>\n                <prdCtg>1</prdCtg>\n                <prdNm>대출상품</prdNm>\n                <cv19SuprCtg>-</cv19SuprCtg>\n                <cv19SuprCtn>-</cv19SuprCtn>\n                <cv19SuprTgtDtlCtn>-</cv19SuprTgtDtlCtn>\n                <mgmDln>상시</mgmDln>\n                <prdCtg2>-</prdCtg2>\n                <fileWrtDt>202504010700</fileWrtDt>\n            </item>\n        </items>\n    </body>\n</response>\n'

# %%
f_soup = bs(f_response, 'xml')
f_soup.select_one("resultCode")
f_soup
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
# <header>
# <resultCode>00</resultCode>
# <resultMsg>NORMAL SERVICE.</resultMsg>
# </header>
# <body>
# <numOfRows>1</numOfRows>
# <pageNo>1</pageNo>
# <totalCount>4741</totalCount>
# <items>
# <item>
# <basYm>202503</basYm>
# <snq>1</snq>
# <finPrdNm>새희망홀씨Ⅱ</finPrdNm>
# <lnLmt>3500만원</lnLmt>
# <irtCtg>변동금리</irtCtg>
# <irt>은행별 상이</irt>
# <maxTotLnTrm>은행별 상이</maxTotLnTrm>
# <maxDfrmTrm>-</maxDfrmTrm>
# <maxRdptTrm>-</maxRdptTrm>
# <rdptMthd>원(리)금균등분할상환</rdptMthd>
# <usge>생계</usge>
# <trgt>근로자</trgt>
# <instCtg>시중은행</instCtg>
# <ofrInstNm>14개 취급은행</ofrInstNm>
# <rsdAreaPamtEqltIstm>전국</rsdAreaPamtEqltIstm>
# <suprTgtDtlCond>연소득 4천만원 이하 (개인신용평점 하위 100분의 20*이하는 5천만원 이하) *23년 4월 기준 NICE 749점, KCB 700점 이하</suprTgtDtlCond>
# <age>없음</age>
# <incm>연소득 4천만원 이하 (개인신용평점 하위 100분의 20*이하는 5천만원 이하)</incm>
# <rsdArea>-</rsdArea>
# <crdtSc>신용평가회사의 개인신용평점이 하위 100분의 20에 해당하는자</crdtSc>
# <anin>-</anin>
# <housHoldCnt>-</housHoldCnt>
# <housAr>-</housAr>
# <lnTgtHous>-</lnTgtHous>
# <rfrcCnpl>취급은행 콜센터, 서민금융콜센터 (국번없이)1397</rfrcCnpl>
# <grnInst>-</grnInst>
# <jnMthd>14개 취급은행 신청방법 문의</jnMthd>
# <rpymdCfe>-</rpymdCfe>
# <lnIcdcst>-</lnIcdcst>
# <ovItrYr>-</ovItrYr>
# <prftAddIrtCond>성실상환자, 사회적 취약계층(기초생활수급권자, 한부모가정, 다자녀가정, 다문화가정, 만 60세 이상 부모부양자, 청년층(만 29세 이하), 고령자(만 65세 이상), 장애인 등), 공신력 있는 금융교육기관에서 금융교육을 이수한 자에 대해 금리우대 (은행별 자율 결정)</prftAddIrtCond>
# <etcRefSbjc>-</etcRefSbjc>
# <hdlInst>취급 은행(14개)</hdlInst>
# <cnpl>취급은행 콜센터, 서민금융콜센터 (국번없이)1397</cnpl>
# <rltSite>취급은행 홈페이지</rltSite>
# <tgtFltr>근로자</tgtFltr>
# <hdlInstDtlVw>취급은행(국민, 신한, 우리, 기업, KEB하나, SC, 농협, 수협, 경남, 광주, 대구, 부산, 전북, 제주)</hdlInstDtlVw>
# <prdExisYn>Y</prdExisYn>
# <cv19Rfrc>-</cv19Rfrc>
# <prdCtg>1</prdCtg>
# <prdNm>대출상품</prdNm>
# <cv19SuprCtg>-</cv19SuprCtg>
# <cv19SuprCtn>-</cv19SuprCtn>
# <cv19SuprTgtDtlCtn>-</cv19SuprTgtDtlCtn>
# <mgmDln>상시</mgmDln>
# <prdCtg2>-</prdCtg2>
# <fileWrtDt>202504010700</fileWrtDt>
# </item>
# </items>
# </body>
# </response>

# %%
f_soup.select("*")
# Out:
# [<response>
#  <header>
#  <resultCode>00</resultCode>
#  <resultMsg>NORMAL SERVICE.</resultMsg>
#  </header>
#  <body>
#  <numOfRows>1</numOfRows>
#  <pageNo>1</pageNo>
#  <totalCount>4741</totalCount>
#  <items>
#  <item>
#  <basYm>202503</basYm>
#  <snq>1</snq>
#  <finPrdNm>새희망홀씨Ⅱ</finPrdNm>
#  <lnLmt>3500만원</lnLmt>
#  <irtCtg>변동금리</irtCtg>
#  <irt>은행별 상이</irt>
#  <maxTotLnTrm>은행별 상이</maxTotLnTrm>
#  <maxDfrmTrm>-</maxDfrmTrm>
#  <maxRdptTrm>-</maxRdptTrm>
#  <rdptMthd>원(리)금균등분할상환</rdptMthd>
#  <usge>생계</usge>
#  <trgt>근로자</trgt>
#  <instCtg>시중은행</instCtg>
#  <ofrInstNm>14개 취급은행</ofrInstNm>
#  <rsdAreaPamtEqltIstm>전국</rsdAreaPamtEqltIstm>
#  <suprTgtDtlCond>연소득 4천만원 이하 (개인신용평점 하위 100분의 20*이하는 5천만원 이하) *23년 4월 기준 NICE 749점, KCB 700점 이하</suprTgtDtlCond>
#  <age>없음</age>
#  <incm>연소득 4천만원 이하 (개인신용평점 하위 100분의 20*이하는 5천만원 이하)</incm>
#  <rsdArea>-</rsdArea>
#  <crdtSc>신용평가회사의 개인신용평점이 하위 100분의 20에 해당하는자</crdtSc>
#  <anin>-</anin>
#  <housHoldCnt>-</housHoldCnt>
#  <housAr>-</housAr>
#  <lnTgtHous>-</lnTgtHous>
#  <rfrcCnpl>취급은행 콜센터, 서민금융콜센터 (국번없이)1397</rfrcCnpl>
#  <grnInst>-</grnInst>
#  <jnMthd>14개 취급은행 신청방법 문의</jnMthd>
#  <rpymdCfe>-</rpymdCfe>
#  <lnIcdcst>-</lnIcdcst>
#  <ovItrYr>-</ovItrYr>
#  <prftAddIrtCond>성실상환자, 사회적 취약계층(기초생활수급권자, 한부모가정, 다자녀가정, 다문화가정, 만 60세 이상 부모부양자, 청년층(만 29세 이하), 고령자(만 65세 이상), 장애인 등), 공신력 있는 금융교육기관에서 금융교육을 이수한 자에 대해 금리우대 (은행별 자율 결정)</prftAddIrtCond>
#  <etcRefSbjc>-</etcRefSbjc>
#  <hdlInst>취급 은행(14개)</hdlInst>
#  <cnpl>취급은행 콜센터, 서민금융콜센터 (국번없이)1397</cnpl>
#  <rltSite>취급은행 홈페이지</rltSite>
#  <tgtFltr>근로자</tgtFltr>
#  <hdlInstDtlVw>취급은행(국민, 신한, 우리, 기업, KEB하나, SC, 농협, 수협, 경남, 광주, 대구, 부산, 전북, 제주)</hdlInstDtlVw>
#  <prdExisYn>Y</prdExisYn>
#  <cv19Rfrc>-</cv19Rfrc>
#  <prdCtg>1</prdCtg>
#  <prdNm>대출상품</prdNm>
#  <cv19SuprCtg>-</cv19SuprCtg>
#  <cv19SuprCtn>-</cv19SuprCtn>
#  <cv19SuprTgtDtlCtn>-</cv19SuprTgtDtlCtn>
#  <mgmDln>상시</mgmDln>
#  <prdCtg2>-</prdCtg2>
#  <fileWrtDt>202504010700</fileWrtDt>
#  </item>
#  </items>
#  </body>
#  </response>,
#  <header>
#  <resultCode>00</resultCode>
#  <resultMsg>NORMAL SERVICE.</resultMsg>
#  </header>,
#  <resultCode>00</resultCode>,
#  <resultMsg>NORMAL SERVICE.</resultMsg>,
#  <body>
#  <numOfRows>1</numOfRows>
#  <pageNo>1</pageNo>
#  <totalCount>4741</totalCount>
#  <items>
#  <item>
#  <basYm>202503</basYm>
#  <snq>1</snq>
#  <finPrdNm>새희망홀씨Ⅱ</finPrdNm>
#  <lnLmt>3500만원</lnLmt>
#  <irtCtg>변동금리</irtCtg>
#  <irt>은행별 상이</irt>
#  <maxTotLnTrm>은행별 상이</maxTotLnTrm>
#  <maxDfrmTrm>-</maxDfrmTrm>
#  <maxRdptTrm>-</maxRdptTrm>
#  <rdptMthd>원(리)금균등분할상환</rdptMthd>
#  <usge>생계</usge>
#  <trgt>근로자</trgt>
#  <instCtg>시중은행</instCtg>
#  <ofrInstNm>14개 취급은행</ofrInstNm>
#  <rsdAreaPamtEqltIstm>전국</rsdAreaPamtEqltIstm>
#  <suprTgtDtlCond>연소득 4천만원 이하 (개인신용평점 하위 100분의 20*이하는 5천만원 이하) *23년 4월 기준 NICE 749점, KCB 700점 이하</suprTgtDtlCond>
#  <age>없음</age>
#  <incm>연소득 4천만원 이하 (개인신용평점 하위 100분의 20*이하는 5천만원 이하)</incm>
#  <rsdArea>-</rsdArea>
#  <crdtSc>신용평가회사의 개인신용평점이 하위 100분의 20에 해당하는자</crdtSc>
#  <anin>-</anin>
#  <housHoldCnt>-</housHoldCnt>
#  <housAr>-</housAr>
#  <lnTgtHous>-</lnTgtHous>
#  <rfrcCnpl>취급은행 콜센터, 서민금융콜센터 (국번없이)1397</rfrcCnpl>
#  <grnInst>-</grnInst>
#  <jnMthd>14개 취급은행 신청방법 문의</jnMthd>
#  <rpymdCfe>-</rpymdCfe>
#  <lnIcdcst>-</lnIcdcst>
#  <ovItrYr>-</ovItrYr>
#  <prftAddIrtCond>성실상환자, 사회적 취약계층(기초생활수급권자, 한부모가정, 다자녀가정, 다문화가정, 만 60세 이상 부모부양자, 청년층(만 29세 이하), 고령자(만 65세 이상), 장애인 등), 공신력 있는 금융교육기관에서 금융교육을 이수한 자에 대해 금리우대 (은행별 자율 결정)</prftAddIrtCond>
#  <etcRefSbjc>-</etcRefSbjc>
#  <hdlInst>취급 은행(14개)</hdlInst>
#  <cnpl>취급은행 콜센터, 서민금융콜센터 (국번없이)1397</cnpl>
#  <rltSite>취급은행 홈페이지</rltSite>
#  <tgtFltr>근로자</tgtFltr>
#  <hdlInstDtlVw>취급은행(국민, 신한, 우리, 기업, KEB하나, SC, 농협, 수협, 경남, 광주, 대구, 부산, 전북, 제주)</hdlInstDtlVw>
#  <prdExisYn>Y</prdExisYn>
#  <cv19Rfrc>-</cv19Rfrc>
#  <prdCtg>1</prdCtg>
#  <prdNm>대출상품</prdNm>
#  <cv19SuprCtg>-</cv19SuprCtg>
#  <cv19SuprCtn>-</cv19SuprCtn>
#  <cv19SuprTgtDtlCtn>-</cv19SuprTgtDtlCtn>
#  <mgmDln>상시</mgmDln>
#  <prdCtg2>-</prdCtg2>
#  <fileWrtDt>202504010700</fileWrtDt>
#  </item>
#  </items>
#  </body>,
#  <numOfRows>1</numOfRows>,
#  <pageNo>1</pageNo>,
#  <totalCount>4741</totalCount>,
#  <items>
#  <item>
#  <basYm>202503</basYm>
#  <snq>1</snq>
#  <finPrdNm>새희망홀씨Ⅱ</finPrdNm>
#  <lnLmt>3500만원</lnLmt>
#  <irtCtg>변동금리</irtCtg>
#  <irt>은행별 상이</irt>
#  <maxTotLnTrm>은행별 상이</maxTotLnTrm>
#  <maxDfrmTrm>-</maxDfrmTrm>
#  <maxRdptTrm>-</maxRdptTrm>
#  <rdptMthd>원(리)금균등분할상환</rdptMthd>
#  <usge>생계</usge>
#  <trgt>근로자</trgt>
#  <instCtg>시중은행</instCtg>
#  <ofrInstNm>14개 취급은행</ofrInstNm>
#  <rsdAreaPamtEqltIstm>전국</rsdAreaPamtEqltIstm>
#  <suprTgtDtlCond>연소득 4천만원 이하 (개인신용평점 하위 100분의 20*이하는 5천만원 이하) *23년 4월 기준 NICE 749점, KCB 700점 이하</suprTgtDtlCond>
#  <age>없음</age>
#  <incm>연소득 4천만원 이하 (개인신용평점 하위 100분의 20*이하는 5천만원 이하)</incm>
#  <rsdArea>-</rsdArea>
#  <crdtSc>신용평가회사의 개인신용평점이 하위 100분의 20에 해당하는자</crdtSc>
#  <anin>-</anin>
#  <housHoldCnt>-</housHoldCnt>
#  <housAr>-</housAr>
#  <lnTgtHous>-</lnTgtHous>
#  <rfrcCnpl>취급은행 콜센터, 서민금융콜센터 (국번없이)1397</rfrcCnpl>
#  <grnInst>-</grnInst>
#  <jnMthd>14개 취급은행 신청방법 문의</jnMthd>
#  <rpymdCfe>-</rpymdCfe>
#  <lnIcdcst>-</lnIcdcst>
#  <ovItrYr>-</ovItrYr>
#  <prftAddIrtCond>성실상환자, 사회적 취약계층(기초생활수급권자, 한부모가정, 다자녀가정, 다문화가정, 만 60세 이상 부모부양자, 청년층(만 29세 이하), 고령자(만 65세 이상), 장애인 등), 공신력 있는 금융교육기관에서 금융교육을 이수한 자에 대해 금리우대 (은행별 자율 결정)</prftAddIrtCond>
#  <etcRefSbjc>-</etcRefSbjc>
#  <hdlInst>취급 은행(14개)</hdlInst>
#  <cnpl>취급은행 콜센터, 서민금융콜센터 (국번없이)1397</cnpl>
#  <rltSite>취급은행 홈페이지</rltSite>
#  <tgtFltr>근로자</tgtFltr>
#  <hdlInstDtlVw>취급은행(국민, 신한, 우리, 기업, KEB하나, SC, 농협, 수협, 경남, 광주, 대구, 부산, 전북, 제주)</hdlInstDtlVw>
#  <prdExisYn>Y</prdExisYn>
#  <cv19Rfrc>-</cv19Rfrc>
#  <prdCtg>1</prdCtg>
#  <prdNm>대출상품</prdNm>
#  <cv19SuprCtg>-</cv19SuprCtg>
#  <cv19SuprCtn>-</cv19SuprCtn>
#  <cv19SuprTgtDtlCtn>-</cv19SuprTgtDtlCtn>
#  <mgmDln>상시</mgmDln>
#  <prdCtg2>-</prdCtg2>
#  <fileWrtDt>202504010700</fileWrtDt>
#  </item>
#  </items>,
#  <item>
#  <basYm>202503</basYm>
#  <snq>1</snq>
#  <finPrdNm>새희망홀씨Ⅱ</finPrdNm>
#  <lnLmt>3500만원</lnLmt>
#  <irtCtg>변동금리</irtCtg>
#  <irt>은행별 상이</irt>
#  <maxTotLnTrm>은행별 상이</maxTotLnTrm>
#  <maxDfrmTrm>-</maxDfrmTrm>
#  <maxRdptTrm>-</maxRdptTrm>
#  <rdptMthd>원(리)금균등분할상환</rdptMthd>
#  <usge>생계</usge>
#  <trgt>근로자</trgt>
#  <instCtg>시중은행</instCtg>
#  <ofrInstNm>14개 취급은행</ofrInstNm>
#  <rsdAreaPamtEqltIstm>전국</rsdAreaPamtEqltIstm>
#  <suprTgtDtlCond>연소득 4천만원 이하 (개인신용평점 하위 100분의 20*이하는 5천만원 이하) *23년 4월 기준 NICE 749점, KCB 700점 이하</suprTgtDtlCond>
#  <age>없음</age>
#  <incm>연소득 4천만원 이하 (개인신용평점 하위 100분의 20*이하는 5천만원 이하)</incm>
#  <rsdArea>-</rsdArea>
#  <crdtSc>신용평가회사의 개인신용평점이 하위 100분의 20에 해당하는자</crdtSc>
#  <anin>-</anin>
#  <housHoldCnt>-</housHoldCnt>
#  <housAr>-</housAr>
#  <lnTgtHous>-</lnTgtHous>
#  <rfrcCnpl>취급은행 콜센터, 서민금융콜센터 (국번없이)1397</rfrcCnpl>
#  <grnInst>-</grnInst>
#  <jnMthd>14개 취급은행 신청방법 문의</jnMthd>
#  <rpymdCfe>-</rpymdCfe>
#  <lnIcdcst>-</lnIcdcst>
#  <ovItrYr>-</ovItrYr>
#  <prftAddIrtCond>성실상환자, 사회적 취약계층(기초생활수급권자, 한부모가정, 다자녀가정, 다문화가정, 만 60세 이상 부모부양자, 청년층(만 29세 이하), 고령자(만 65세 이상), 장애인 등), 공신력 있는 금융교육기관에서 금융교육을 이수한 자에 대해 금리우대 (은행별 자율 결정)</prftAddIrtCond>
#  <etcRefSbjc>-</etcRefSbjc>
#  <hdlInst>취급 은행(14개)</hdlInst>
#  <cnpl>취급은행 콜센터, 서민금융콜센터 (국번없이)1397</cnpl>
#  <rltSite>취급은행 홈페이지</rltSite>
#  <tgtFltr>근로자</tgtFltr>
#  <hdlInstDtlVw>취급은행(국민, 신한, 우리, 기업, KEB하나, SC, 농협, 수협, 경남, 광주, 대구, 부산, 전북, 제주)</hdlInstDtlVw>
#  <prdExisYn>Y</prdExisYn>
#  <cv19Rfrc>-</cv19Rfrc>
#  <prdCtg>1</prdCtg>
#  <prdNm>대출상품</prdNm>
#  <cv19SuprCtg>-</cv19SuprCtg>
#  <cv19SuprCtn>-</cv19SuprCtn>
#  <cv19SuprTgtDtlCtn>-</cv19SuprTgtDtlCtn>
#  <mgmDln>상시</mgmDln>
#  <prdCtg2>-</prdCtg2>
#  <fileWrtDt>202504010700</fileWrtDt>
#  </item>,
#  <basYm>202503</basYm>,
#  <snq>1</snq>,
#  <finPrdNm>새희망홀씨Ⅱ</finPrdNm>,
#  <lnLmt>3500만원</lnLmt>,
#  <irtCtg>변동금리</irtCtg>,
#  <irt>은행별 상이</irt>,
#  <maxTotLnTrm>은행별 상이</maxTotLnTrm>,
#  <maxDfrmTrm>-</maxDfrmTrm>,
#  <maxRdptTrm>-</maxRdptTrm>,
#  <rdptMthd>원(리)금균등분할상환</rdptMthd>,
#  <usge>생계</usge>,
#  <trgt>근로자</trgt>,
#  <instCtg>시중은행</instCtg>,
#  <ofrInstNm>14개 취급은행</ofrInstNm>,
#  <rsdAreaPamtEqltIstm>전국</rsdAreaPamtEqltIstm>,
#  <suprTgtDtlCond>연소득 4천만원 이하 (개인신용평점 하위 100분의 20*이하는 5천만원 이하) *23년 4월 기준 NICE 749점, KCB 700점 이하</suprTgtDtlCond>,
#  <age>없음</age>,
#  <incm>연소득 4천만원 이하 (개인신용평점 하위 100분의 20*이하는 5천만원 이하)</incm>,
#  <rsdArea>-</rsdArea>,
#  <crdtSc>신용평가회사의 개인신용평점이 하위 100분의 20에 해당하는자</crdtSc>,
#  <anin>-</anin>,
#  <housHoldCnt>-</housHoldCnt>,
#  <housAr>-</housAr>,
#  <lnTgtHous>-</lnTgtHous>,
#  <rfrcCnpl>취급은행 콜센터, 서민금융콜센터 (국번없이)1397</rfrcCnpl>,
#  <grnInst>-</grnInst>,
#  <jnMthd>14개 취급은행 신청방법 문의</jnMthd>,
#  <rpymdCfe>-</rpymdCfe>,
#  <lnIcdcst>-</lnIcdcst>,
#  <ovItrYr>-</ovItrYr>,
#  <prftAddIrtCond>성실상환자, 사회적 취약계층(기초생활수급권자, 한부모가정, 다자녀가정, 다문화가정, 만 60세 이상 부모부양자, 청년층(만 29세 이하), 고령자(만 65세 이상), 장애인 등), 공신력 있는 금융교육기관에서 금융교육을 이수한 자에 대해 금리우대 (은행별 자율 결정)</prftAddIrtCond>,
#  <etcRefSbjc>-</etcRefSbjc>,
#  <hdlInst>취급 은행(14개)</hdlInst>,
#  <cnpl>취급은행 콜센터, 서민금융콜센터 (국번없이)1397</cnpl>,
#  <rltSite>취급은행 홈페이지</rltSite>,
#  <tgtFltr>근로자</tgtFltr>,
#  <hdlInstDtlVw>취급은행(국민, 신한, 우리, 기업, KEB하나, SC, 농협, 수협, 경남, 광주, 대구, 부산, 전북, 제주)</hdlInstDtlVw>,
#  <prdExisYn>Y</prdExisYn>,
#  <cv19Rfrc>-</cv19Rfrc>,
#  <prdCtg>1</prdCtg>,
#  <prdNm>대출상품</prdNm>,
#  <cv19SuprCtg>-</cv19SuprCtg>,
#  <cv19SuprCtn>-</cv19SuprCtn>,
#  <cv19SuprTgtDtlCtn>-</cv19SuprTgtDtlCtn>,
#  <mgmDln>상시</mgmDln>,
#  <prdCtg2>-</prdCtg2>,
#  <fileWrtDt>202504010700</fileWrtDt>]

# %%
fresult = {}
for item in f_soup.select("items"):
    for tags in item:
        for tag in tags:
            f_response=r2.text
            f_response=f_response.replace("\n","")
            f_response=f_response.replace(" ","")
#             print(tag)
#             fresult.setdefault(tag.name, []).append(tag.text)
fresult

#         for tag in tags:
#             fresult.setdefault(tag.name, []).append(tag.text)
# fresult
# df = pd.DataFrame(fresult)
# df
# Out:
# {}
