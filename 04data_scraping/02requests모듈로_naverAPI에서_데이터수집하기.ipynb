# %% [markdown]
# # 1.requrests 모듈 : HTTP 프로토콜을 사용할 수 있게 해주는 모듈
# * [requests](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %% [markdown]
# # 2 requests 모듈 설치
# * conda install requests
# * pip install requests

# %% [markdown]
# # 3. requests 모듈 사용법
# * 1) 모듈 불러오기 : import requests
# * 2) url 변수에 저장
# * 3) url 파라미터
#     * payload = {파라미터1 : value1, 파라미터2 : value2
# * 4) header
#     * headers = {key : value}
# * 5) HTTP 요청 보내기 : get,post
#     * get : r = requests.get(url, params = payload, headers = headers)
#     * post : r = requests.post(url, data={key:valu})
# * 6) 만들어진 url 확인
#     * print(r.url)
# * 7) 응답 코드 확인 : print(r.status_code)
# * 8) 응답 요소 출력 : r.text, r.json, r.content, r.json()

# %%
import pandas as pd

# %%
start_num2 = 1
for s_num in range(11):
    start_num2 += 100
    print(start_num2)

# %%
import requests
url = "https://openapi.naver.com/v1/search/blog.json"
Cliend_Id = "TaVTw3HnrpVGJDDGj3ym"
Cliend_Pw = "46NsuGC17a"
payload = dict(query = '핀테크1', display = 10, start= 1, sort ="sim")
headers = {"X-Naver-Client-Id" : Cliend_Id, "X-Naver-Client-Secret" : Cliend_Pw }
r = requests.get(url, params=payload, headers = headers)
print(r.url)
print(r.status_code)
response = r.json()
response
r_response = pd.DataFrame(response)
r_response

# %% [markdown]
#  * 모든 검색결과를 가져오기 위해서는 여러페이지 정보를 수집
#  * 전체결과 / 1페이지 표시 개수 = 전체 페이지 수
#  * start 부분 + 1페이지 표지 개수 = 다음 페이지 데이터 수집 가능
#  * 반복문을 이용해서 start에 100씩 더해서 최대 100이 되도록 하면 최대한 많은 데이터 수집 가능

# %%
import requests

# %%
url = "https://openapi.naver.com/v1/search/blog"

# %%
payload = {'query': '핀테크1', 'display' : 100, 'start': 1, 'sort':"sim" }
headers = {"X-Naver-Client-Id" : "TaVTw3HnrpVGJDDGj3ym", "X-Naver-Client-Secret" : "46NsuGC17a"}
r = requests.get(url, params=payload, headers = headers)
print(r.url)
print(r.status_code)
# status code : Informational responses (100 – 199)
# Successful responses (200 – 299)
# Redirection messages (300 – 399)
# Client error responses (400 – 499)
# Server error responses (500 – 599)
# 200번이 올바른 결과(OK)
data = r.json()
data
# r.text
# Out:
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC1&display=100&start=1&sort=sim
# 200
# {'lastBuildDate': 'Tue, 01 Apr 2025 13:24:07 +0900',
#  'total': 299627,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '이것도 <b>핀테크</b>? 운전 습관에 따라 보험료가... ',
#    'link': 'https://blog.naver.com/koreafintech/223803803517',
#    'description': '이것도 <b>핀테크</b>? #<b>1</b>편 운전 습관에 따라 보험료가 달라지는 BBI (Behavior-Based Insurance) 인슈어테크로... 오늘은 보험의 핀테크인 인슈어테크(InsureTech) 중 “운전행태 기반 자동차 보험 (BBI, Behavior-Based Insurance)... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20250321'},
#   {'title': '[진로체험] 제물포중학교 <b>핀테크</b> 금융 IT 전문가 진로프로그램',
#    'link': 'https://blog.naver.com/sys1748/223743582618',
#    'description': '2024년 한 해 학생들이 선정한 최고의 과목이에요^^ 제물포중학교 진로 체험 학습 제물포중학교 직업 체험은 6개 학급 대상 1개 과목 2차시 진로교육으로 진행했어요 ㅎㅎ 차례 강의 명 <b>1</b> <b>핀테크</b> 금융 IT 전문가... ',
#    'bloggername': '한국융합과학교육원',
# ...

# %%
payload

# %%
headers

# %% [markdown]
# 네이버 검색 API를 이용해서 책을 검색하고 결과를 데이터프레임으로 만드세요
# * 검색어는 input()을 이용해서 입력받은 값을 이용하세요.

# %%
import requests
import pandas as pd

# %%
bookurl = "https://openapi.naver.com/v1/search/book.json"
bookname = input("책이름을 검색하세요: ")

payload = {'query': bookname, 'display' : 100, 'start': 1, 'sort':"sim" }
headers = {"X-Naver-Client-Id": "TaVTw3HnrpVGJDDGj3ym","X-Naver-Client-Secret" : "46NsuGC17a"}
r = requests.get(bookurl, params=payload, headers = headers)
data = r.json()
data

# %%
result2 = {}
for item in data['items'] :
    for key, value in item.items():
        result2.setdefault(key, []).append(value)
df2 = pd.DataFrame(result2)
df2

# %%
result2 = {}
for item in data['items'] :
    for key, value in item.items():
        result2.setdefault(key, []).append(value)
df2 = pd.DataFrame(result2)
df2

# %% [markdown]
# * 풀이

# %%
import requests
import pandas as pd
# pandas 에 넣어서 표로 나오게 하려면 딕셔너리 형태로 넣어야 함.

# %%
def json_unpack(data):
    result = {}
    for item in data['items'] :
        for key, value in item.items():
            result.setdefault(key, []).append(value)
    df = pd.DataFrame(result)
    return df

# %%
keyword = input("키워드를 입력해 주세요: ")
# Out:
# 키워드를 입력해 주세요: 핀테크

# %%
url = "https://openapi.naver.com/v1/search/book.json"
headers = {"X-Naver-Client-Id": "TaVTw3HnrpVGJDDGj3ym","X-Naver-Client-Secret" : "46NsuGC17a"}
params  = dict(query=keyword, display = 100, start = 1, sort = "sim")
r = requests.get(url, params=params, headers=headers)
print(r.url)
print(r.status_code)
data = r.json()

print("전체데이터 검색 수 :", data['total'], "검색할 페이지수:", (int(data['total'])//100)+1)
# Out:
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# 전체데이터 검색 수 : 106 검색할 페이지수: 2

# %%
result_df = json_unpack(data)
result_df
# Out:
#                                                 title  \
# 0                                                 핀테크
# 1                            핀테크 (IT와 금융이 만나는 새로운 세상)
# 2                            핀테크 4.0 (핀테크 혁명과 금융의 미래)
# 3                                        핀테크와 법 (제3판)
# 4          핀테크 전쟁 (세계 금융 시장의 거대한 트렌드 | 새로운 돈의 시대가 온다)
# ..                                                ...
# 95  2025 4차산업 AI기업·스타트업 주소록 (3D프린터, IOT, VR, 가상현실,...
# 96           핀테크 산업의 국내외 시장동향과 관련 서비스 현황 및 기술/활용사례 분석
# 97              핀테크(FinTech)산업 동향전망과 정보보호산업 기술현황 실태분석
# 98          스마트 금융 시대를 선도하는 핀테크 관련 신사업전략 모색을 위한 종합 분석
# 99   IoT기반 근거리 무선통신 핀테크 산업 현황과 무선전력 전송 및 무선충전 기술개발 동향
#
#                                                  link  \
# 0   https://search.shopping.naver.com/book/catalog...
# 1   https://search.shopping.naver.com/book/catalog...
# 2   https://search.shopping.naver.com/book/catalog...
# 3   https://search.shopping.naver.com/book/catalog...
# ...

# %%
data['total']
# Out:
# 106

# %%
r = requests.get(url, params=params, headers=headers)
print(r.url)
print(r.status_code)
data = r.json()
data
result_df = json_unpack(data)
result_df

# %%
result = {}
for item in data['items'] :
    for key, value in item.items():
        result.setdefault(key, []).append(value)
df = pd.DataFrame(result)
df

# %% [markdown]
# # 네이버 API로 검색한 결과 최대한 가져오기
# * 1회 네이버 서버에 요청
# * 응답해서 total 찾아서 display로 나누어 총 반복할 페이지 산출
# * 반복문 작성 및 종료 조건 설정
# * 1페이지 결과를 데이터 프레임으로 만들고 리스트에 append
# * 반복이 끝난 후 리스트에 aapend 된 데이터 프레임을 1개로 합치기

# %%
import requests
import pandas as pd

# %%
search = input("키워드를 입력해 주세요: ")

# %%
url = "https://openapi.naver.com/v1/search/book.json"
headers = {"X-Naver-Client-Id": "TaVTw3HnrpVGJDDGj3ym","X-Naver-Client-Secret" : "46NsuGC17a"}
params  = dict(query=keyword, display = 100, start = 1, sort = "sim")
r = requests.get(url, params=params, headers=headers)
print(r.url)
print(r.status_code)
data = r.json()

print("전체데이터 검색 수 :", data['total'], "검색할 페이지수:", (int(data['total'])//100)+1)

# %%
df_list = []

for page in range(1, max_pages + 1):
    start = (page - 1) * display + 1
    if start > total_results:
        for item in data['items'] :
            for key, value in item.items():
                result = {}
                result.setdefault(key, []).append(value)
df = pd.DataFrame(result)
df

# %%
total_results = data['total']
display = 100
max_pages = (total_results // display) + 1

# %%
df_list = []

for page in range(1, max_pages + 1):
    start = (page - 1) * display + 1  # 시작 인덱스 계산
    if start > total_results:  # 종료 조건 (total보다 큰 start는 의미 없음)
        break

# %%
print(df_list)

# %%
payload['start'] = start
response = requests.get(bookurl, params=payload, headers=headers)
page_data = response.json()

# %%
df_l = pd.DataFrame(df_list)
df_l

# %%
def json_unpack(data):
    result = {}
    for item in data['items'] :
        for key, value in item.items():
            result.setdefault(key, []).append(value)
    df = pd.DataFrame(result)
    return df

# %% [markdown]
# # 풀이 1. while

# %%
import requests
import pandas as pd

# %%
keyword = input("검색 키워드를 입력하세요")

# %%
all_data2 = []
start = 1
while True:
    url = "https://openapi.naver.com/v1/search/book.json"
    headers = {"X-Naver-Client-Id": "TaVTw3HnrpVGJDDGj3ym","X-Naver-Client-Secret" : "46NsuGC17a"}
    params  = dict(query=keyword, display = 100, start = start, sort = "sim")
    r = requests.get(url, params=params, headers=headers)
    print(r.url)
    print(r.status_code)
    data = r.json()
    n_data = data['total']
    total_pages = (int(data['total'])//100)+1
    print("전체데이터 검색 수 :", n_data, "검색할 페이지수:", total_pages)
    result_df = json_unpack(data)
    all_data2.append(result_df)
    if start == 1000 :
        break
    elif start < 901 :
        start += 100
    elif start == 901:
        start += 99

# %%
len(all_data2)

# %%
final_result2 = pd.concat(all_data2)
final_result2 = final_result2.reset_index(drop=True)
final_result2

# %%
final_result2.to_csv("네이버검색_책_파이썬.csv", encoding="utf-8-sig", index=False)

# %%
url = "https://openapi.naver.com/v1/search/book.json"
headers = {"X-Naver-Client-Id": "TaVTw3HnrpVGJDDGj3ym","X-Naver-Client-Secret" : "46NsuGC17a"}
params  = dict(query=keyword, display = 100, start = 1000, sort = "sim")
r = requests.get(url, params=params, headers=headers)
print(r.url)
print(r.status_code)
data = r.json()
print("전체데이터 검색 수 :", data['total'], "검색할 페이지수:", (int(data['total'])//100)+1)
result_df = json_unpack(data)
result_df

# %% [markdown]
# # 풀이 2. for

# %%
all_data = []

# %%
url = "https://openapi.naver.com/v1/search/book.json"
headers = {"X-Naver-Client-Id": "TaVTw3HnrpVGJDDGj3ym","X-Naver-Client-Secret" : "46NsuGC17a"}
params  = dict(query=keyword, display = 100, start = 1, sort = "sim")
r = requests.get(url, params=params, headers=headers)
print(r.url)
print(r.status_code)
data = r.json()
n_data = data['total']
total_pages = (int(data['total'])//100)+1

print("전체데이터 검색 수 :", n_data, "검색할 페이지수:", total_pages)

result_df = json_unpack(data)
all_data.append(result_df)

# %%
start = 101
for page in range(total_pages) :
    print(f"{page+1} {total_pages} 수집중" , end="\r")
    url = "https://openapi.naver.com/v1/search/book.json"
    headers = {"X-Naver-Client-Id": "TaVTw3HnrpVGJDDGj3ym","X-Naver-Client-Secret" : "46NsuGC17a"}
    params  = dict(query=keyword, display = 100, start = start, sort = "sim")
    r = requests.get(url, params=params, headers=headers)
    print(r.url)
    print(r.status_code)
    data = r.json()
    n_data = data['total']
    total_pages = (int(data['total'])//100)+1
#     print("전체데이터 검색 수 :", n_data, "검색할 페이지수:", total_pages)
    result_df = json_unpack(data)
    all_data.append(result_df)
    if start == 1000:
        break
    elif start < 900 :
        start += 100
        # elif 는 조건을 만족하면 다른 elif 문은 실행 안함.
    elif start == 901 :
        start += 99

# %%
len(all_data)

# %%
final_result = pd.concat(all_data)
final_result = final_result.reset_index(drop=True) # 각 테이블마다 번호가 인덱싱 되어 있는걸 합친 테이블에 다시 인덱싱하기
final_result

# %% [markdown]
# # 뉴스, 블로그, 책 한번에 저장하기

# %%
all_data3 = []
start = 1
for category in ["blog", "news", "book"]:
    while True:
        url = f"https://openapi.naver.com/v1/search/{category}.json"
        headers = {"X-Naver-Client-Id": "TaVTw3HnrpVGJDDGj3ym","X-Naver-Client-Secret" : "46NsuGC17a"}
        params  = dict(query=keyword, display = 100, start = 1000, sort = "sim")
        r = requests.get(url, params=params, headers=headers)
        print(r.url)
        print(r.status_code)
        data = r.json()
        n_data = data['total']
        total_pages = (int(data['total'])//100)+1
        print("전체데이터 검색 수 :", n_data, "검색할 페이지수:", total_pages)
        result_df = json_unpack(data)
        all_data3.append(result_df)
        if start == 1000 :
            break
        elif start < 901 :
            start += 100
        elif start == 901:
            start += 99
final_result3 = pd.concat(all_data3)
final_result3 = final_result3.reset_index(drop=True)
final_result3
# Out:
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1000&sort=sim
# 200
# 전체데이터 검색 수 : 456179 검색할 페이지수: 4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1000&sort=sim
# 200
# 전체데이터 검색 수 : 456179 검색할 페이지수: 4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1000&sort=sim
# 200
# 전체데이터 검색 수 : 456179 검색할 페이지수: 4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1000&sort=sim
# 200
# 전체데이터 검색 수 : 456179 검색할 페이지수: 4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1000&sort=sim
# 200
# 전체데이터 검색 수 : 456179 검색할 페이지수: 4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1000&sort=sim
# 200
# 전체데이터 검색 수 : 456179 검색할 페이지수: 4562
# ...

# %%
test = pd.DataFrame(final_result3)
test
# Out:
#                                                   title  \
# 0           제2회 ｢금융회사-<b>핀테크</b>기업 상호만남(Meet-Up)｣ 행사 개최
# 1                 금융당국, <b>핀테크</b> 우수기업 K-Fintech 30 선정
# 2                   당신의 지갑 속 혁명: <b>핀테크</b>가 바꾸는 금융의 미래
# 3                                     <b>핀테크</b>란 무엇인가?
# 4               스테이블코인과 <b>핀테크</b> 기업의 역할: 미래를 선도하는 두 축
# ...                                                 ...
# 1195         아이쿠카, 수원중부경찰서와 아동 실종 예방 '지문 사전등록 캠페인' 진...
# 1196                    헥토파이낸셜, 무인 유통매장 관리 솔루션 '오더인' 출시
# 1197         우리금융, 금융권 최초 블록체인 스타트업 육성에 본격화 '디노랩 B센터...
# 1198         업비트 송치형 회장, 가상자산 이상거래 신고센터 운영...“건전하고 투...
# 1199  <b>핀테크</b>·TCB 8개사 CEO “AI 활용 확대로 신용평가 고도화 투자 ...
#
#                                                    link  \
# 0           https://blog.naver.com/blogfsc/223399382531
# 1         https://blog.naver.com/happykdic/223271903101
# 2       https://blog.naver.com/housingk07r/223785252660
# 3     https://blog.naver.com/consultant712/223801138183
# ...

# %% [markdown]
# # 블로그, 뉴스 책, 데이터 각각 저장하기

# %%
import requests
import time
keyword = input("검색할 키워드를 입력해 주세요 :")
response_blog=[]
response_news = []
response_book = []

for category in ["blog", "news", "book"]:
    response_result = []
    page = 1
    start_num2 = 1
    while True:
        url = f"https://openapi.naver.com/v1/search/{category}.json"
        headers = {"X-Naver-Client-Id": "TaVTw3HnrpVGJDDGj3ym",
                   "X-Naver-Client-Secret" : "46NsuGC17a"}
        params  = dict(query=keyword, display = 100, start = start_num2, sort = "sim")

        r = requests.get(url, params=params, headers=headers)
        print(r.url, end="\r")
        print(r.status_code, end="\r")
        response = r.json()
        total_pages = (response['total']//100)+1

        if category == 'blog':
            response_blog.append(response)
        elif category == 'news' :
            response_news.append(response)
        elif category == 'book' :
            response_book.append(response)

        if start_num2 == 1000 :
            break
        elif start_num2 < 901 :
            start_num2 += 100
        elif start_num2 == 901:
            start_num2 += 99

        if page < total_pages:
            page += 1
        else :
            break
        time.sleep(0.2)
r1=pd.DataFrame(response)
r1
# Out:
# 검색할 키워드를 입력해 주세요 :인공지능
# 200ps://openapi.naver.com/v1/search/book.json?query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&display=100&start=1000&sort=sim
#                       lastBuildDate  total  start  display  \
# 0   Tue, 01 Apr 2025 14:30:34 +0900   2202   1000      100
# 1   Tue, 01 Apr 2025 14:30:34 +0900   2202   1000      100
# 2   Tue, 01 Apr 2025 14:30:34 +0900   2202   1000      100
# 3   Tue, 01 Apr 2025 14:30:34 +0900   2202   1000      100
# 4   Tue, 01 Apr 2025 14:30:34 +0900   2202   1000      100
# ..                              ...    ...    ...      ...
# 95  Tue, 01 Apr 2025 14:30:34 +0900   2202   1000      100
# 96  Tue, 01 Apr 2025 14:30:34 +0900   2202   1000      100
# 97  Tue, 01 Apr 2025 14:30:34 +0900   2202   1000      100
# 98  Tue, 01 Apr 2025 14:30:34 +0900   2202   1000      100
# 99  Tue, 01 Apr 2025 14:30:34 +0900   2202   1000      100
#
#                                                 items
# 0   {'title': '미래 인공지능으로 황제재벌기 1 (보랑빛노을 현대 판타지 장편소...
# ...

# %%
import requests
import time
keyword = input("검색할 키워드를 입력해 주세요 :")

def naver_search(category):
    response_result = []
    page = 1
    start_num2 = 1
    while True:
        url = f"https://openapi.naver.com/v1/search/{category}.json"
        headers = {"X-Naver-Client-Id": "TaVTw3HnrpVGJDDGj3ym",
                   "X-Naver-Client-Secret" : "46NsuGC17a"}
        params  = dict(query=keyword, display = 100, start = start_num2, sort = "sim")

        r = requests.get(url, params=params, headers=headers)
        response = r.json()
        total_pages = (response['total']//100)+1
        response_result=totalpages.append(response)
        
        if start_num2 == 1000 :
            break
        elif start_num2 < 901 :
            start_num2 += 100
        elif start_num2 == 901:
            start_num2 += 99

        if page < total_pages:
            page += 1
        else :
            break
        time.sleep(0.2)
        
    return response_result
# Out:
# 검색할 키워드를 입력해 주세요 :인공지능

# %%
df = pd.DataFrame(response_result)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 df = pd.DataFrame(response_result)
#       2 df
#
# NameError: name 'response_result' is not defined

# %%
import time
keyword = input("검색할 키워드를 입력해 주세요: ")
for category in ["blog", "news", "book"] :
    naver_search_result = naver_search(category)
    print(f"{category}_search_result:{len(naver_search_result)}")
# Out:
# 검색할 키워드를 입력해 주세요: 인공지능
# blog_search_result:0r.com/v1/search/blog.json?query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&display=100&start=1000&sort=sim
# news_search_result:0r.com/v1/search/news.json?query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&display=100&start=1000&sort=sim
# book_search_result:0r.com/v1/search/book.json?query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&display=100&start=1000&sort=sim

# %%
len(naver_search_result)
# Out:
# 0

# %%
import pandas as pd

# %%
def json_unpack(all_data):
    final_result={}
    for page in all_data :
        for items in page['items'][:1]:
            for key, value in item.items():
                final_result.setdefault(key, []).append(value)

    a = pd.DataFrame(final_result)
    return a

# %%
for jsons, cat in zip([response_blog,response_news, response_book], ["blog","news","book"]) :
    unpack_result = json_unpack(jsons)
    unpack_result.to_csv(f"naver_[cat]_result.csv", encoding="utf-8", index=False)

# %% [markdown]
# # 3개 카테고리 수집 코드를 함수화하기

# %%
a
# Out:
#                              title  \
# 0   <b>핀테크</b> 뜻, 예시, 성공적인 사례 알아보기
# 1   <b>핀테크</b> 뜻, 예시, 성공적인 사례 알아보기
# 2   <b>핀테크</b> 뜻, 예시, 성공적인 사례 알아보기
# 3   <b>핀테크</b> 뜻, 예시, 성공적인 사례 알아보기
# 4   <b>핀테크</b> 뜻, 예시, 성공적인 사례 알아보기
# 5   <b>핀테크</b> 뜻, 예시, 성공적인 사례 알아보기
# 6   <b>핀테크</b> 뜻, 예시, 성공적인 사례 알아보기
# 7   <b>핀테크</b> 뜻, 예시, 성공적인 사례 알아보기
# 8   <b>핀테크</b> 뜻, 예시, 성공적인 사례 알아보기
# 9   <b>핀테크</b> 뜻, 예시, 성공적인 사례 알아보기
# 10  <b>핀테크</b> 뜻, 예시, 성공적인 사례 알아보기
#
#                                                link  \
# 0   https://blog.naver.com/haseobang83/223657527445
# 1   https://blog.naver.com/haseobang83/223657527445
# 2   https://blog.naver.com/haseobang83/223657527445
# 3   https://blog.naver.com/haseobang83/223657527445
# 4   https://blog.naver.com/haseobang83/223657527445
# 5   https://blog.naver.com/haseobang83/223657527445
# 6   https://blog.naver.com/haseobang83/223657527445
# 7   https://blog.naver.com/haseobang83/223657527445
# 8   https://blog.naver.com/haseobang83/223657527445
# ...
