# %% [markdown]
# # 상권정보 데이터 수집

# %%
import requests
import pandas as pd
import time

# %%
def unpack_data(response):
    result = {}
    for item in response['body']['items']:
        for key, value in zip(response['header']['columns'], item.values()):
            result.setdefault(key, []).append(value)
    df = pd.DataFrame(result)
    return df

# %%
page = 1
result_dfs = []
while True:
    url = "http://apis.data.go.kr/B553077/api/open/sdsc2/storeListInUpjong"
    service_key = "8Ym5dhmVJdr12XzGnyYrQjSBS1QuRBYK8yHfx65JCl4vACM9uLKo8fxCVOFJkPB71llD7F2rOEROZnHgNGoj3A=="
    payload = dict(servicekey=service_key, divId="indsSclsCd", 
                  key="I21006", numOfRows=1000, pageNo=page, type="json")
    r = requests.get(url, params=payload)
    print(r.url, end="\r")
    print(r.status_code, end="\r")
    
    response = r.json()
    
    total_page = (response['body']['totalCount'] // 1000) + 1
    
    result_dfs.append(unpack_data(response))        
    
    print(f"{page}/{total_page} 수집중", end="\r")
    if page < total_page:
        page += 1
    else:
        break
    time.sleep(0.2)
        
result = pd.concat(result_dfs)    
result = result.reset_index(drop=True)
result.to_csv("공공데이터_상권정보_202504.csv", encoding="utf-8", index=False)
# Out:
# [                   상가업소번호        상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \8Ym5dhmVJdr12XzGnyYrQjSBS1QuRBYK8yHfx65JCl4vACM9uLKo8fxCVOFJkPB71llD7F2rOEROZnHgNGoj3A%3D%3D&divId=indsSclsCd&key=I21006&numOfRows=1000&pageNo=1&type=json
# 0    MA010120220800445252     가마로닭강정              I2       음식      I210
# 1    MA010120220800445378    수원왕갈비통닭  보라매점        I2       음식      I210
# 2    MA010120220800430361       페리카나              I2       음식      I210
# 3    MA010120220800445715       치킨89              I2       음식      I210
# 4    MA010120220800439275      또바기치킨              I2       음식      I210
# ..                    ...        ...   ...       ...      ...       ...
# 995  MA010120220800526797       페리카나              I2       음식      I210
# 996  MA010120220800533653        비비큐   석수점        I2       음식      I210
# 997  MA010120220800547453       푸드모아              I2       음식      I210
# 998  MA010120220800526994       치킨인류              I2       음식      I210
# 999  MA010120220800527119  네네치킨밀양삼문점              I2       음식      I210
#
#     상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0      기타 간이    I21006       치킨   I56193  ...  1159010500102240001017670
# 1      기타 간이    I21006       치킨   I56213  ...  1159010800104150005004103
# 2      기타 간이    I21006       치킨   I56193  ...  1159010700102130007006364
# 3      기타 간이    I21006       치킨   I56193  ...  1159010900103460008001825
# 4      기타 간이    I21006       치킨   I56193  ...  1156013200103470294013808
# ..       ...       ...      ...      ...  ...                        ...
# 995    기타 간이    I21006       치킨   I56193  ...  4155025026100630014014599
# 996    기타 간이    I21006       치킨   I56193  ...  4117110200103040023012812
# 997    기타 간이    I21006       치킨   M71531  ...  1150010500100000000000005
# 998    기타 간이    I21006       치킨   I56193  ...  4150025330106790003000001
# 999    기타 간이    I21006       치킨   I56193  ...  4827010400107290004000001
#
#          건물명                         도로명주소   구우편번호  신우편번호 동정보 층정보 호정보  \
# 0          제             서울특별시 동작구 서달로 151  156861  06973       1
# 1                   서울특별시 동작구 여의대방로24가길 12  156811  07055       1
# 2                        서울특별시 동작구 사당로 168  156879  07030
# 3      노블레스빌           서울특별시 동작구 보라매로 98-5  156847  07053
# 4                      서울특별시 영등포구 가마산로 439  150848  07382
# ..       ...                           ...     ...    ...  ..  ..  ..
# 995                 경기도 안성시 공도읍 고무다리길 10-1  456825  17562
# 996                  경기도 안양시 만안구 석천로 164-1  430806  13969       1
# 997  보타닉파크타워           서울특별시 강서구 마곡중앙6로 11  157805  07801
# 998           경기도 이천시 부발읍 경충대로2050번길 15-46  467866  17332       1
# 999                     경상남도 밀양시 미리벌중앙로 85  627150  50434       1
#
#              경도         위도
# 0    126.961535  37.506975
# 1    126.921008  37.498774
# 2    126.967572  37.486813
# 3    126.928484  37.497932
# 4    126.905292  37.505322
# ..          ...        ...
# 995  127.169648  36.998410
# 996  126.907387  37.411582
# 997  126.828654  37.560872
# 998  127.493131  37.250713
# 999  128.747223  35.485028
#
# [1000 rows x 39 columns]]
# [                   상가업소번호        상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \8Ym5dhmVJdr12XzGnyYrQjSBS1QuRBYK8yHfx65JCl4vACM9uLKo8fxCVOFJkPB71llD7F2rOEROZnHgNGoj3A%3D%3D&divId=indsSclsCd&key=I21006&numOfRows=1000&pageNo=2&type=json
# 0    MA010120220800445252     가마로닭강정              I2       음식      I210
# 1    MA010120220800445378    수원왕갈비통닭  보라매점        I2       음식      I210
# 2    MA010120220800430361       페리카나              I2       음식      I210
# 3    MA010120220800445715       치킨89              I2       음식      I210
# 4    MA010120220800439275      또바기치킨              I2       음식      I210
# ..                    ...        ...   ...       ...      ...       ...
# 995  MA010120220800526797       페리카나              I2       음식      I210
# 996  MA010120220800533653        비비큐   석수점        I2       음식      I210
# 997  MA010120220800547453       푸드모아              I2       음식      I210
# 998  MA010120220800526994       치킨인류              I2       음식      I210
# 999  MA010120220800527119  네네치킨밀양삼문점              I2       음식      I210
#
#     상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0      기타 간이    I21006       치킨   I56193  ...  1159010500102240001017670
# 1      기타 간이    I21006       치킨   I56213  ...  1159010800104150005004103
# 2      기타 간이    I21006       치킨   I56193  ...  1159010700102130007006364
# 3      기타 간이    I21006       치킨   I56193  ...  1159010900103460008001825
# 4      기타 간이    I21006       치킨   I56193  ...  1156013200103470294013808
# ..       ...       ...      ...      ...  ...                        ...
# 995    기타 간이    I21006       치킨   I56193  ...  4155025026100630014014599
# 996    기타 간이    I21006       치킨   I56193  ...  4117110200103040023012812
# 997    기타 간이    I21006       치킨   M71531  ...  1150010500100000000000005
# 998    기타 간이    I21006       치킨   I56193  ...  4150025330106790003000001
# 999    기타 간이    I21006       치킨   I56193  ...  4827010400107290004000001
#
#          건물명                         도로명주소   구우편번호  신우편번호 동정보 층정보 호정보  \
# 0          제             서울특별시 동작구 서달로 151  156861  06973       1
# 1                   서울특별시 동작구 여의대방로24가길 12  156811  07055       1
# 2                        서울특별시 동작구 사당로 168  156879  07030
# 3      노블레스빌           서울특별시 동작구 보라매로 98-5  156847  07053
# 4                      서울특별시 영등포구 가마산로 439  150848  07382
# ..       ...                           ...     ...    ...  ..  ..  ..
# 995                 경기도 안성시 공도읍 고무다리길 10-1  456825  17562
# 996                  경기도 안양시 만안구 석천로 164-1  430806  13969       1
# 997  보타닉파크타워           서울특별시 강서구 마곡중앙6로 11  157805  07801
# 998           경기도 이천시 부발읍 경충대로2050번길 15-46  467866  17332       1
# 999                     경상남도 밀양시 미리벌중앙로 85  627150  50434       1
#
#              경도         위도
# 0    126.961535  37.506975
# 1    126.921008  37.498774
# 2    126.967572  37.486813
# 3    126.928484  37.497932
# 4    126.905292  37.505322
# ..          ...        ...
# 995  127.169648  36.998410
# 996  126.907387  37.411582
# 997  126.828654  37.560872
# 998  127.493131  37.250713
# 999  128.747223  35.485028
#
# [1000 rows x 39 columns],                    상가업소번호       상호명 지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 0    MA010120220801085477     비에이치씨            I2       음식      I210    기타 간이
# 1    MA010120220801085743      림스치킨            I2       음식      I210    기타 간이
# 2    MA010120220801093615  도르리숯불바베큐            I2       음식      I210    기타 간이
# 3    MA010120220801086312   신포꼬꼬닭강정            I2       음식      I210    기타 간이
# 4    MA010120220801086358      페리카나            I2       음식      I210    기타 간이
# ..                    ...       ...  ..       ...      ...       ...      ...
# 995  MA010120220801181183       황가네            I2       음식      I210    기타 간이
# 996  MA010120220801181239    바베큐와춤을            I2       음식      I210    기타 간이
# 997  MA010120220801182550     비비큐치킨            I2       음식      I210    기타 간이
# 998  MA010120220801182616      명품치킨            I2       음식      I210    기타 간이
# 999  MA010120220801183040      투투치킨            I2       음식      I210    기타 간이
#
#     상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호         건물명  \
# 0      I21006       치킨   I56193  ...  2811013800100980552051751
# 1      I21006       치킨   I56193  ...  2817010600112500001020729
# 2      I21006       치킨   I56193  ...  2817010200101280011103365
# 3      I21006       치킨   I56193  ...  2820010100112710004026722
# 4      I21006       치킨   I56193  ...  2823710500102010003102265
# ..        ...      ...      ...  ...                        ...         ...
# 995    I21006       치킨   I56193  ...  1138010800100080048045438
# 996    I21006       치킨   I56193  ...  2824510100105560000054267   유승와이드빌아파트
# 997    I21006       치킨   I56193  ...  2824510200110860003030629        계산동외
# 998    I21006       치킨   I56193  ...  2824510300108620030074693
# 999    I21006       치킨   I56193  ...  2824510300109120003142691  도두리마을동보아파트
#
#                       도로명주소   구우편번호  신우편번호 동정보 층정보 호정보          경도         위도
# 0     인천광역시 중구 월미로248번길 5-1  400201  22303       1      126.598118  37.474060
# 1    인천광역시 미추홀구 인하로298번길 27  402208  22230       1      126.681280  37.446707
# 2       인천광역시 미추홀구 인주대로 179  402818  22180              126.656976  37.455784
# 3    인천광역시 남동구 호구포로790번길 12  405839  21534              126.719896  37.452571
# 4         인천광역시 부평구 후정동로 15  403863  21318              126.737770  37.518836
# ..                      ...     ...    ...  ..  ..  ..         ...        ...
# 995      서울특별시 은평구 연서로10길 5  122895  03399              126.915944  37.607494
# 996        인천광역시 계양구 새풀로 31  407832  21104              126.698817  37.526185
# 997         인천광역시 계양구 용종로 2  407813  21071              126.741394  37.534053
# 998    인천광역시 계양구 봉오대로 679-1  407824  21091       1      126.724457  37.530915
# 999       인천광역시 계양구 도두리로 46  407772  21081       1      126.739087  37.533552
#
# [1000 rows x 39 columns]]

# %%
# !pip install openpyxl

# %%
ori_data = pd.read_excel("./data/소상공인시장진흥공단_상가(상권)정보_업종분류(2302)_및_연계표_v1.0.xlsx", engine='openpyxl', header=[1])
# Out:
#     대분류코드          대분류명 중분류코드              중분류명   소분류코드            소분류명
# 0      G2           소매업  G202  자동차 부품 및 내장품 소매업  G20201         타이어 소매업
# 1      G2           소매업  G202  자동차 부품 및 내장품 소매업  G20202      자동차 부품 소매업
# 2      G2           소매업  G203    모터사이클 및 부품 소매업  G20301  모터사이클 및 부품 소매업
# 3      G2           소매업  G204            종합 소매업  G20404            슈퍼마켓
# 4      G2           소매업  G204            종합 소매업  G20405             편의점
# ..    ...           ...   ...               ...     ...             ...
# 242    S2  수리 및 개인 서비스업  S209               세탁업  S20902          셀프 빨래방
# 243    S2  수리 및 개인 서비스업  S210    장례식장 및 관련 서비스업  S21001            장례식장
# 244    S2  수리 및 개인 서비스업  S210    장례식장 및 관련 서비스업  S21002      화장터/묘지/납골당
# 245    S2  수리 및 개인 서비스업  S211          기타 개인서비스  S21101            예식장업
# 246    S2  수리 및 개인 서비스업  S211          기타 개인서비스  S21105      결혼 상담 서비스업
#
# [247 rows x 6 columns]

# %%
for code, name in zip(ori_data['소분류코드'], ori_data['소분류명']):
    page = 1
    result_dfs = []
    while True:
        url = "http://apis.data.go.kr/B553077/api/open/sdsc2/storeListInUpjong"
        service_key = "8Ym5dhmVJdr12XzGnyYrQjSBS1QuRBYK8yHfx65JCl4vACM9uLKo8fxCVOFJkPB71llD7F2rOEROZnHgNGoj3A=="
        payload = dict(servicekey=service_key, divId="indsSclsCd", 
                      key=code, numOfRows=1000, pageNo=page, type="json")
        r = requests.get(url, params=payload)
        print(r.url, end="\r")
        print(r.status_code, end="\r")

        response = r.json()
        total_page = (response['body']['totalCount'] // 1000) + 1
        result_dfs.append(unpack_data(response))
        print(f"{page}/{total_page} 수집중", end="\r")
        if page < total_page:
            page += 1
        else:
            break
        time.sleep(0.2)

    result = pd.concat(result_dfs)    
    result = result.reset_index(drop=True)
    result.to_csv(f"공공데이터_{name}_상권정보_202504.csv", encoding="utf-8", index=False)
# Out:
# G20201
# G20202
# G20301
# G20404
# G20405
# G20499
# G20501
# G20502
# G20503
# G20504
# G20505
# G20506
# G20507
# G20508
# G20509
# G20601
# G20602
# G20603
# G20604
# G20701
# G20801
# G20802
# G20803
# G20901
# G20902
# G20903
# G20904
# G20905
# G20906
# G20907
# G20908
# G20909
# G20910
# G20911
# G21001
# G21002
# G21003
# G21099
# G21101
# G21201
# G21202
# G21203
# G21301
# G21302
# G21303
# G21304
# G21305
# G21306
# G21401
# G21402
# G21403
# G21501
# G21502
# G21503
# G21601
# G21602
# G21603
# G21701
# G21801
# G21802
# G21901
# G22001
# G22199
# G22201
# I10101
# I10102
# I10103
# I10104
# I10201
# I10299
# I20101
# I20102
# I20103
# I20104
# I20105
# I20106
# I20107
# I20108
# I20109
# I20110
# I20111
# I20112
# I20113
# I20199
# I20201
# I20202
# I20301
# I20302
# I20303
# I20399
# I20401
# I20402
# I20403
# I20499
# I20501
# I20599
# I20601
# I20701
# I20702
# I21001
# I21002
# I21003
# I21004
# I21005
# I21006
# I21007
# I21008
# I21099
# I21101
# I21102
# I21103
# I21104
# I21201
# L10203
# M10301
# M10302
# M10303
# M10306
# M10307
# M10399
# M10401
# M10402
# M10499
# M10501
# M10502
# M10503
# M10504
# M10599
# M10601
# M10703
# M10901
# M10902
# M10903
# M10904
# M10999
# M11101
# M11201
# M11202
# M11203
# M11204
# M11301
# M11401
# M11502
# M11504
# N10101
# N10201
# N10202
# N10203
# N10301
# N10401
# N10402
# N10403
# N10501
# N10599
# N10703
# N10799
# N10802
# N10805
# N10901
# N10999
# N11001
# N11002
# N11003
# N11004
# N11099
# N11101
# N11102
# N11199
# P10501
# P10601
# P10603
# P10605
# P10607
# P10609
# P10611
# P10613
# P10615
# P10617
# P10619
# P10621
# P10623
# P10625
# P10627
# P10629
# P10701
# P10799
# Q10101
# Q10102
# Q10103
# Q10104
# Q10105
# Q10201
# Q10202
# Q10203
# Q10204
# Q10205
# Q10206
# Q10207
# Q10208
# Q10209
# Q10210
# Q10211
# Q10212
# Q10402
# R10202
# R10306
# R10307
# R10308
# R10309
# R10310
# R10311
# R10312
# R10313
# R10314
# R10316
# R10402
# R10404
# R10405
# R10406
# R10407
# R10408
# R10409
# R10410
# R10414
# R10499
# S20101
# S20201
# S20301
# S20302
# S20401
# S20501
# S20601
# S20602
# S20603
# S20699
# S20701
# S20702
# S20703
# S20801
# S20802
# S20803
# S20901
# S20902
# S21001
# S21002
# S21101
# S21105
